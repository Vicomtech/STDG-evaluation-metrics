# %% [markdown]
# # TSTR CTGAN Dataset A - Diabetes

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home directory of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'SYNTHETIC DATASETS/CTGAN/A_Diabetes_Data_Synthetic_CTGAN.csv')
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                      'A1Cresult','change','diabetesMed','readmitted']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0         178760744     61269320  Female  [60-70)                 3
# 1         275127896     37904511    Male  [50-60)                 3
# 2          88957358     23026313  Female  [70-80)                 2
# 3         362071111    114265419  Female  [50-60)                 1
# 4         160779558     92169994    Male  [40-50)                 1
# ...             ...          ...     ...      ...               ...
# 81407      55916783       962667  Female  [70-80)                 1
# 81408     383410659     88478903  Female  [50-60)                 1
# 81409     163294538     52575141  Female  [80-90)                 1
# 81410     112081539      4929517  Female  [70-80)                 1
# 81411      27107267     20836275    Male  [50-60)                 2
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   1                 4
# 1                            1                   1                 3
# 2                            1                  10                 3
# 3                            1                   7                 2
# 4                            1                   7                 4
# ...                        ...                 ...               ...
# 81407                        6                   7                 4
# 81408                        1                   7                10
# 81409                        3                   7                 9
# 81410                       11                   7                 6
# 81411                        1                   4                 2
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      55               1               22                  0
# 1                      61               2               17                  0
# 2                      46               0               17                  0
# 3                      46               0                7                  0
# 4                      35               1               12                  0
# ...                   ...             ...              ...                ...
# 81407                  69               0               17                  0
# 81408                  45               2               10                  0
# 81409                  45               2               16                  0
# 81410                  78               2               17                  0
# 81411                  30               0                8                  0
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     0                 0                 7          None
# 1                     0                 0                 7          None
# 2                     0                 0                 5          None
# 3                     0                 0                 7          None
# 4                     1                 2                 7          None
# ...                 ...               ...               ...           ...
# 81407                 0                 1                 9          None
# 81408                 1                 1                 8          None
# 81409                 0                 1                 9          None
# 81410                 0                 0                 4          None
# 81411                 0                 1                 4          >200
#
#       A1Cresult change diabetesMed readmitted
# 0            >8     Ch         Yes         NO
# 1          None     Ch         Yes         NO
# 2          None     No         Yes         NO
# 3          None     No          No         NO
# 4          None     No          No        >30
# ...         ...    ...         ...        ...
# 81407        >8     No         Yes         NO
# 81408      Norm     Ch         Yes        >30
# 81409      None     No          No         NO
# 81410      None     No         Yes         NO
# 81411      None     No         Yes        >30
#
# [81412 rows x 20 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/A_Diabetes_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0         110939484     19274094  Female  [70-80)                 1
# 1         170328306     65634327    Male  [50-60)                 1
# 2         245688426    100657359  Female  [60-70)                 3
# 3         150826224     83144448    Male  [30-40)                 2
# 4         135993852     65234214  Female  [60-70)                 1
# ...             ...          ...     ...      ...               ...
# 20349      61022328     93447369    Male  [80-90)                 1
# 20350     189128682     97296336    Male  [40-50)                 3
# 20351     251922018     84358062  Female  [70-80)                 1
# 20352     214461468     98468460    Male  [70-80)                 2
# 20353     128407860     42489621    Male  [80-90)                 3
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   6                11
# 1                            1                   1                 1
# 2                            6                   1                 4
# 3                            1                   1                12
# 4                            2                   7                 1
# ...                        ...                 ...               ...
# 20349                        1                   7                 6
# 20350                        1                   1                 2
# 20351                        1                   7                 9
# 20352                        1                   7                 2
# 20353                        1                   1                 7
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      68               0               20                  0
# 1                      20               0                7                  0
# 2                      21               3               23                  1
# 3                      28               0               19                  0
# 4                      21               0                6                  0
# ...                   ...             ...              ...                ...
# 20349                  51               1               17                  0
# 20350                  49               1               16                  0
# 20351                  41               2               17                  3
# 20352                  22               0                5                  0
# 20353                  16               4               14                  0
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     0                 0                 5          None
# 1                     0                 0                 8          None
# 2                     0                 2                 7          None
# 3                     0                 1                 7          None
# 4                     0                 0                 7          None
# ...                 ...               ...               ...           ...
# 20349                 0                 0                 8          None
# 20350                 0                 2                 9          None
# 20351                 0                 0                 9          None
# 20352                 0                 0                 7          None
# 20353                 0                 0                 9          None
#
#       A1Cresult change diabetesMed readmitted
# 0          None     No         Yes         NO
# 1          None     No         Yes         NO
# 2          None     No         Yes         NO
# 3          None     No         Yes        >30
# 4          None     No         Yes        <30
# ...         ...    ...         ...        ...
# 20349      None     No         Yes        <30
# 20350      None     Ch         Yes        <30
# 20351      None     No         Yes        >30
# 20352      None     No         Yes        >30
# 20353      None     No         Yes         NO
#
# [20354 rows x 20 columns]

# %%
target = 'readmitted'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (81412, 20)
# readmitted
# <30     6053
# >30    19624
# NO     55735
# dtype: int64
# #####################################
# Test data
# (20354, 20)
# readmitted
# <30     2285
# >30     7117
# NO     10952
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'readmitted'
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                    'A1Cresult','change','diabetesMed']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array(range(3)), np.array(range(10)), np.array(range(9)), np.array(range(29)), np.array(range(21)), 
                np.array(range(4)), np.array(range(4)), np.array(range(2)), np.array(range(2))]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((81412, 94), (81412,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((20354, 94), (20354,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    7.7s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.3s finished
#   model  accuracy  precision  recall     f1
# 0    RF     0.556     0.4953   0.556  0.472

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.5436     0.4845  0.5436  0.4902

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall     f1
# 0    DT    0.4733     0.4585  0.4733  0.464

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.2739     0.4301  0.2739  0.3008

# %% [markdown]
# Iteration 236, loss = 0.44159405
# Iteration 237, loss = 0.43887640
# Iteration 238, loss = 0.44292616
# Iteration 239, loss = 0.43936197
# Iteration 240, loss = 0.43793412
# Iteration 241, loss = 0.43812738
# Iteration 242, loss = 0.43621211
# Iteration 243, loss = 0.44317461
# Iteration 244, loss = 0.43746282
# Iteration 245, loss = 0.43835792
# Iteration 246, loss = 0.43703480
# Iteration 247, loss = 0.43943225
# Iteration 248, loss = 0.43602537
# Iteration 249, loss = 0.43503198
# Iteration 250, loss = 0.43768331
# Iteration 251, loss = 0.43779224
# Iteration 252, loss = 0.43522501
# Iteration 253, loss = 0.43666868
# Iteration 254, loss = 0.43848212
# Iteration 255, loss = 0.43779337
# Iteration 256, loss = 0.43566546
# Iteration 257, loss = 0.43786909
# Iteration 258, loss = 0.43302970
# Iteration 259, loss = 0.43406465
# Iteration 260, loss = 0.43412032
# Iteration 261, loss = 0.43388541
# Iteration 262, loss = 0.43211833
# Iteration 263, loss = 0.43603260
# Iteration 264, loss = 0.43381841
# Iteration 265, loss = 0.43087930
# Iteration 266, loss = 0.43340112
# Iteration 267, loss = 0.45017019
# Iteration 268, loss = 0.43335888
# Iteration 269, loss = 0.43416865
# Iteration 270, loss = 0.43205739
# Iteration 271, loss = 0.43289135
# Iteration 272, loss = 0.43065146
# Iteration 273, loss = 0.43100740
# Iteration 274, loss = 0.43031150
# Iteration 275, loss = 0.42837829
# Iteration 276, loss = 0.43020728
# Iteration 277, loss = 0.43406111
# Iteration 278, loss = 0.42982561
# Iteration 279, loss = 0.42945593
# Iteration 280, loss = 0.43182997
# Iteration 281, loss = 0.42943510
# Iteration 282, loss = 0.43145367
# Iteration 283, loss = 0.42866253
# Iteration 284, loss = 0.42807080
# Iteration 285, loss = 0.42751990
# Iteration 286, loss = 0.42681183
# Iteration 287, loss = 0.42663101
# Iteration 288, loss = 0.42743383
# Iteration 289, loss = 0.43107259
# Iteration 290, loss = 0.42772299
# Iteration 291, loss = 0.42722697
# Iteration 292, loss = 0.42567271
# Iteration 293, loss = 0.42611184
# Iteration 294, loss = 0.42858648
# Iteration 295, loss = 0.42522126
# Iteration 296, loss = 0.42773169
# Iteration 297, loss = 0.42664074
# Iteration 298, loss = 0.42536322
# Iteration 299, loss = 0.42630185
# Iteration 300, loss = 0.42623668
#   model  accuracy  precision  recall      f1
# 0   MLP    0.5113     0.4775  0.5113  0.4847

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_ctgan.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.5560     0.4953  0.5560  0.4720
# 1   KNN    0.5436     0.4845  0.5436  0.4902
# 2    DT    0.4733     0.4585  0.4733  0.4640
# 3   SVM    0.2739     0.4301  0.2739  0.3008
# 4   MLP    0.5113     0.4775  0.5113  0.4847
