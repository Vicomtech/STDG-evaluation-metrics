# %% [markdown]
# # TSTR SDV Dataset A - Diabetes

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home directory of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)


#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'SYNTHETIC DATASETS/SDV/A_Diabetes_Data_Synthetic_SDV.csv')
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                      'A1Cresult','change','diabetesMed','readmitted']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0         -28804602     41361052    Male  [50-60)                 3
# 1          44295622     42357617  Female  [50-60)                 1
# 2         120436308     80879232  Female  [70-80)                 3
# 3         240827370     61122839    Male  [60-70)                 1
# 4         291306426    102313008  Female  [40-50)                 1
# ...             ...          ...     ...      ...               ...
# 81407     188165461    111175154    Male  [80-90)                 3
# 81408      39568334     17946770    Male  [80-90)                 8
# 81409     211986492     54424724    Male  [40-50)                 1
# 81410     238225577     70292306    Male  [80-90)                 1
# 81411     278154698     95047945    Male  [60-70)                 1
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   6                 5
# 1                           25                   7                 6
# 2                            1                   2                 9
# 3                            3                   7                 5
# 4                            1                   1                 7
# ...                        ...                 ...               ...
# 81407                        1                   4                 5
# 81408                        1                   7                 8
# 81409                        6                   7                 2
# 81410                        1                   7                 4
# 81411                        1                   7                 3
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      14               2               26                  1
# 1                      77               2               15                  1
# 2                      49               2               18                  0
# 3                      65               2               33                  1
# 4                      69               2               21                 -1
# ...                   ...             ...              ...                ...
# 81407                  34               2               13                  0
# 81408                  65               3               15                  0
# 81409                  42               1               18                 -2
# 81410                  30              -1               19                  1
# 81411                  48               0               19                  1
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                    -1                 1                 6          None
# 1                     0                 1                 8          None
# 2                     1                 1                 9          None
# 3                    -1                 1                 9          None
# 4                     0                 2                 7          None
# ...                 ...               ...               ...           ...
# 81407                 1                 0                 8          None
# 81408                 0                 2                 9          None
# 81409                 2                 2                10          None
# 81410                -1                 2                 7          None
# 81411                 1                 1                 6          None
#
#       A1Cresult change diabetesMed readmitted
# 0          None     No          No         NO
# 1          None     No         Yes        >30
# 2          None     No         Yes         NO
# 3          None     Ch         Yes         NO
# 4          None     No         Yes         NO
# ...         ...    ...         ...        ...
# 81407      None     No         Yes         NO
# 81408      None     No         Yes        >30
# 81409      None     No         Yes         NO
# 81410      None     No          No         NO
# 81411      None     No         Yes        >30
#
# [81412 rows x 20 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/A_Diabetes_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0         110939484     19274094  Female  [70-80)                 1
# 1         170328306     65634327    Male  [50-60)                 1
# 2         245688426    100657359  Female  [60-70)                 3
# 3         150826224     83144448    Male  [30-40)                 2
# 4         135993852     65234214  Female  [60-70)                 1
# ...             ...          ...     ...      ...               ...
# 20349      61022328     93447369    Male  [80-90)                 1
# 20350     189128682     97296336    Male  [40-50)                 3
# 20351     251922018     84358062  Female  [70-80)                 1
# 20352     214461468     98468460    Male  [70-80)                 2
# 20353     128407860     42489621    Male  [80-90)                 3
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   6                11
# 1                            1                   1                 1
# 2                            6                   1                 4
# 3                            1                   1                12
# 4                            2                   7                 1
# ...                        ...                 ...               ...
# 20349                        1                   7                 6
# 20350                        1                   1                 2
# 20351                        1                   7                 9
# 20352                        1                   7                 2
# 20353                        1                   1                 7
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      68               0               20                  0
# 1                      20               0                7                  0
# 2                      21               3               23                  1
# 3                      28               0               19                  0
# 4                      21               0                6                  0
# ...                   ...             ...              ...                ...
# 20349                  51               1               17                  0
# 20350                  49               1               16                  0
# 20351                  41               2               17                  3
# 20352                  22               0                5                  0
# 20353                  16               4               14                  0
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     0                 0                 5          None
# 1                     0                 0                 8          None
# 2                     0                 2                 7          None
# 3                     0                 1                 7          None
# 4                     0                 0                 7          None
# ...                 ...               ...               ...           ...
# 20349                 0                 0                 8          None
# 20350                 0                 2                 9          None
# 20351                 0                 0                 9          None
# 20352                 0                 0                 7          None
# 20353                 0                 0                 9          None
#
#       A1Cresult change diabetesMed readmitted
# 0          None     No         Yes         NO
# 1          None     No         Yes         NO
# 2          None     No         Yes         NO
# 3          None     No         Yes        >30
# 4          None     No         Yes        <30
# ...         ...    ...         ...        ...
# 20349      None     No         Yes        <30
# 20350      None     Ch         Yes        <30
# 20351      None     No         Yes        >30
# 20352      None     No         Yes        >30
# 20353      None     No         Yes         NO
#
# [20354 rows x 20 columns]

# %%
target = 'readmitted'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (81412, 20)
# readmitted
# <30     4990
# >30    28648
# NO     47774
# dtype: int64
# #####################################
# Test data
# (20354, 20)
# readmitted
# <30     2285
# >30     7117
# NO     10952
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'readmitted'
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                    'A1Cresult','change','diabetesMed']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array(range(3)), np.array(range(10)), np.array(range(9)), np.array(range(29)), np.array(range(21)), 
                np.array(range(4)), np.array(range(4)), np.array(range(2)), np.array(range(2))]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((81412, 94), (81412,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((20354, 94), (20354,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    8.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.3s finished
#   model  accuracy  precision  recall      f1
# 0    RF     0.546     0.4615   0.546  0.4239

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.5131     0.4537  0.5131  0.4626

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.4556     0.4351  0.4556  0.4441

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.3049     0.4405  0.3049  0.3256

# %% [markdown]
# Iteration 236, loss = 0.58851008
# Iteration 237, loss = 0.58892586
# Iteration 238, loss = 0.58785740
# Iteration 239, loss = 0.59112215
# Iteration 240, loss = 0.58917516
# Iteration 241, loss = 0.58741721
# Iteration 242, loss = 0.58855593
# Iteration 243, loss = 0.58718159
# Iteration 244, loss = 0.58938368
# Iteration 245, loss = 0.58675328
# Iteration 246, loss = 0.58650621
# Iteration 247, loss = 0.58790129
# Iteration 248, loss = 0.58652045
# Iteration 249, loss = 0.58631973
# Iteration 250, loss = 0.58375936
# Iteration 251, loss = 0.58545587
# Iteration 252, loss = 0.58656290
# Iteration 253, loss = 0.58549351
# Iteration 254, loss = 0.58508733
# Iteration 255, loss = 0.58561867
# Iteration 256, loss = 0.59014472
# Iteration 257, loss = 0.58402147
# Iteration 258, loss = 0.58290417
# Iteration 259, loss = 0.58525754
# Iteration 260, loss = 0.58517386
# Iteration 261, loss = 0.58307133
# Iteration 262, loss = 0.58464771
# Iteration 263, loss = 0.58283828
# Iteration 264, loss = 0.58345153
# Iteration 265, loss = 0.58737324
# Iteration 266, loss = 0.58173506
# Iteration 267, loss = 0.58201561
# Iteration 268, loss = 0.58081730
# Iteration 269, loss = 0.58348249
# Iteration 270, loss = 0.58349759
# Iteration 271, loss = 0.58278400
# Iteration 272, loss = 0.58172201
# Iteration 273, loss = 0.58194117
# Iteration 274, loss = 0.58021636
# Iteration 275, loss = 0.57899691
# Iteration 276, loss = 0.58115933
# Iteration 277, loss = 0.58179691
# Iteration 278, loss = 0.57921490
# Iteration 279, loss = 0.58105182
# Iteration 280, loss = 0.58107759
# Iteration 281, loss = 0.58172003
# Iteration 282, loss = 0.57988779
# Iteration 283, loss = 0.58450552
# Iteration 284, loss = 0.58031227
# Iteration 285, loss = 0.57667395
# Iteration 286, loss = 0.57856981
# Iteration 287, loss = 0.57996898
# Iteration 288, loss = 0.58003088
# Iteration 289, loss = 0.58297562
# Iteration 290, loss = 0.57659630
# Iteration 291, loss = 0.57594202
# Iteration 292, loss = 0.57651162
# Iteration 293, loss = 0.57983411
# Iteration 294, loss = 0.57892555
# Iteration 295, loss = 0.57836833
# Iteration 296, loss = 0.57620905
# Iteration 297, loss = 0.57550405
# Iteration 298, loss = 0.57802776
# Iteration 299, loss = 0.57758937
# Iteration 300, loss = 0.57480214
#   model  accuracy  precision  recall      f1
# 0   MLP    0.4951     0.4457  0.4951  0.4591

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_sdv.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.5460     0.4615  0.5460  0.4239
# 1   KNN    0.5131     0.4537  0.5131  0.4626
# 2    DT    0.4556     0.4351  0.4556  0.4441
# 3   SVM    0.3049     0.4405  0.3049  0.3256
# 4   MLP    0.4951     0.4457  0.4951  0.4591
