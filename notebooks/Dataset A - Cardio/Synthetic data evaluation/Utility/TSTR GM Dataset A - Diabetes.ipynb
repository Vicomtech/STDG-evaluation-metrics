# %% [markdown]
# # TSTR GM Dataset A - Diabetes

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home directory of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'SYNTHETIC DATASETS/GM/A_Diabetes_Data_Synthetic_GM.csv')
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                      'A1Cresult','change','diabetesMed','readmitted']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#        encounter_id  patient_nbr  gender       age admission_type_id  \
# 0          55263844     73425914    Male   [70-80)                 2
# 1          70034002     36749733  Female   [80-90)                 2
# 2         428180152    136154611    Male   [70-80)                 3
# 3          36215451      5314375  Female   [70-80)                 6
# 4         132810221     70592062  Female   [70-80)                 5
# ...             ...          ...     ...       ...               ...
# 81407      52044663     14996419  Female  [90-100)                 1
# 81408     156727385    105999805  Female   [50-60)                 1
# 81409      81094768     31322560  Female   [40-50)                 3
# 81410      10611239     25019256    Male   [40-50)                 2
# 81411     160663646     26115229    Male   [50-60)                 2
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   1                 4
# 1                           13                   1                 5
# 2                            1                   1                 3
# 3                           25                   7                 2
# 4                            3                   6                 2
# ...                        ...                 ...               ...
# 81407                        1                   7                 7
# 81408                        6                  17                 2
# 81409                        3                  17                 0
# 81410                        1                   7                13
# 81411                        6                   7                 3
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      46               1               11                  0
# 1                      44               2               21                  2
# 2                      60               0               18                  0
# 3                      48               0               17                  0
# 4                      12               0               15                  0
# ...                   ...             ...              ...                ...
# 81407                  70               0               27                  0
# 81408                  55               0               14                  0
# 81409                  23               0               10                  2
# 81410                  43               1               13                  0
# 81411                  70               0               11                  1
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     0                 0                 7          None
# 1                     0                 1                 8          None
# 2                     0                 0                 6          None
# 3                     0                 2                 8          None
# 4                     0                 0                 5          None
# ...                 ...               ...               ...           ...
# 81407                 0                 0                 8          None
# 81408                 0                 0                 9          None
# 81409                 1                 0                 4          None
# 81410                 0                 0                 6          None
# 81411                 0                 0                 7          None
#
#       A1Cresult change diabetesMed readmitted
# 0          None     No         Yes        >30
# 1          None     No         Yes        <30
# 2          None     No          No        <30
# 3          None     Ch         Yes         NO
# 4          None     No         Yes         NO
# ...         ...    ...         ...        ...
# 81407      None     Ch         Yes         NO
# 81408      None     No          No         NO
# 81409      None     No         Yes        >30
# 81410      None     No         Yes        <30
# 81411      None     No         Yes         NO
#
# [81412 rows x 20 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/A_Diabetes_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0         110939484     19274094  Female  [70-80)                 1
# 1         170328306     65634327    Male  [50-60)                 1
# 2         245688426    100657359  Female  [60-70)                 3
# 3         150826224     83144448    Male  [30-40)                 2
# 4         135993852     65234214  Female  [60-70)                 1
# ...             ...          ...     ...      ...               ...
# 20349      61022328     93447369    Male  [80-90)                 1
# 20350     189128682     97296336    Male  [40-50)                 3
# 20351     251922018     84358062  Female  [70-80)                 1
# 20352     214461468     98468460    Male  [70-80)                 2
# 20353     128407860     42489621    Male  [80-90)                 3
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   6                11
# 1                            1                   1                 1
# 2                            6                   1                 4
# 3                            1                   1                12
# 4                            2                   7                 1
# ...                        ...                 ...               ...
# 20349                        1                   7                 6
# 20350                        1                   1                 2
# 20351                        1                   7                 9
# 20352                        1                   7                 2
# 20353                        1                   1                 7
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      68               0               20                  0
# 1                      20               0                7                  0
# 2                      21               3               23                  1
# 3                      28               0               19                  0
# 4                      21               0                6                  0
# ...                   ...             ...              ...                ...
# 20349                  51               1               17                  0
# 20350                  49               1               16                  0
# 20351                  41               2               17                  3
# 20352                  22               0                5                  0
# 20353                  16               4               14                  0
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     0                 0                 5          None
# 1                     0                 0                 8          None
# 2                     0                 2                 7          None
# 3                     0                 1                 7          None
# 4                     0                 0                 7          None
# ...                 ...               ...               ...           ...
# 20349                 0                 0                 8          None
# 20350                 0                 2                 9          None
# 20351                 0                 0                 9          None
# 20352                 0                 0                 7          None
# 20353                 0                 0                 9          None
#
#       A1Cresult change diabetesMed readmitted
# 0          None     No         Yes         NO
# 1          None     No         Yes         NO
# 2          None     No         Yes         NO
# 3          None     No         Yes        >30
# 4          None     No         Yes        <30
# ...         ...    ...         ...        ...
# 20349      None     No         Yes        <30
# 20350      None     Ch         Yes        <30
# 20351      None     No         Yes        >30
# 20352      None     No         Yes        >30
# 20353      None     No         Yes         NO
#
# [20354 rows x 20 columns]

# %%
target = 'readmitted'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (81412, 20)
# readmitted
# <30     9183
# >30    29458
# NO     42771
# dtype: int64
# #####################################
# Test data
# (20354, 20)
# readmitted
# <30     2285
# >30     7117
# NO     10952
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'readmitted'
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                    'A1Cresult','change','diabetesMed']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array(range(3)), np.array(range(10)), np.array(range(9)), np.array(range(29)), np.array(range(21)), 
                np.array(range(4)), np.array(range(4)), np.array(range(2)), np.array(range(2))]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((81412, 94), (81412,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((20354, 94), (20354,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    8.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.4s finished
#   model  accuracy  precision  recall      f1
# 0    RF    0.5562     0.4932  0.5562  0.5097

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.4995     0.4606  0.4995  0.4744

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.4296     0.4424  0.4296  0.4351

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.2608     0.4459  0.2608  0.2883

# %% [markdown]
# ## 8. Train and evaluate Multilayer Perceptron Classifier

# %%
mlp_results = train_evaluate_model('MLP', x_train, y_train, x_test, y_test)
results = results.append(mlp_results, ignore_index=True)
mlp_results
# Out:
# Iteration 1, loss = 0.94057579
# Iteration 2, loss = 0.93284634
# Iteration 3, loss = 0.93137452
# Iteration 4, loss = 0.92961596
# Iteration 5, loss = 0.92743647
# Iteration 6, loss = 0.92556973
# Iteration 7, loss = 0.92340373
# Iteration 8, loss = 0.92044318
# Iteration 9, loss = 0.91794586
# Iteration 10, loss = 0.91447144
# Iteration 11, loss = 0.91083015
# Iteration 12, loss = 0.90655639
# Iteration 13, loss = 0.90284928
# Iteration 14, loss = 0.89903177
# Iteration 15, loss = 0.89378237
# Iteration 16, loss = 0.88981780
# Iteration 17, loss = 0.88472541
# Iteration 18, loss = 0.88075516
# Iteration 19, loss = 0.87597363
# Iteration 20, loss = 0.87204065
# Iteration 21, loss = 0.86738098
# Iteration 22, loss = 0.86345999
# Iteration 23, loss = 0.85979932
# Iteration 24, loss = 0.85589837
# Iteration 25, loss = 0.85140336
# Iteration 26, loss = 0.84815942
# Iteration 27, loss = 0.84447657
# Iteration 28, loss = 0.84125881
# Iteration 29, loss = 0.83775880
# Iteration 213, loss = 0.67256363
# Iteration 214, loss = 0.67313714
# Iteration 215, loss = 0.67101072
# Iteration 216, loss = 0.67107387
# Iteration 217, loss = 0.67362992
# Iteration 218, loss = 0.66984268
# Iteration 219, loss = 0.67234017
# Iteration 220, loss = 0.67020652
# Iteration 221, loss = 0.67069863
# Iteration 222, loss = 0.66859929
# Iteration 223, loss = 0.67010030
# Iteration 224, loss = 0.66952852
# Iteration 225, loss = 0.66844879
# Iteration 226, loss = 0.66942391
# Iteration 227, loss = 0.66866796
# Iteration 228, loss = 0.66874297
# Iteration 229, loss = 0.67057770
# Iteration 230, loss = 0.66863511
# Iteration 231, loss = 0.66758744
# Iteration 232, loss = 0.66736979
# Iteration 233, loss = 0.66748784
# Iteration 234, loss = 0.66932155
# Iteration 235, loss = 0.66622135
# Iteration 236, loss = 0.66567467
# Iteration 237, loss = 0.66541502
# Iteration 238, loss = 0.66766408
# Iteration 239, loss = 0.66603797
# Iteration 240, loss = 0.66560082
# Iteration 241, loss = 0.66469637
# Iteration 242, loss = 0.66556752
# Iteration 243, loss = 0.66745770
# Iteration 244, loss = 0.66356380
# Iteration 245, loss = 0.66279553
# Iteration 246, loss = 0.66316566
# Iteration 247, loss = 0.66518214
# Iteration 248, loss = 0.66396690
# Iteration 249, loss = 0.66371744
# Iteration 250, loss = 0.66433261
# Iteration 251, loss = 0.66492009
# Iteration 252, loss = 0.66221288
# Iteration 253, loss = 0.66156314
# Iteration 254, loss = 0.66225907
# Iteration 255, loss = 0.66175559
# Iteration 256, loss = 0.66252390
# Iteration 257, loss = 0.66092488
# Iteration 258, loss = 0.66184165
# Iteration 259, loss = 0.66159792
# Iteration 260, loss = 0.66071741
# Iteration 261, loss = 0.66024358
# Iteration 262, loss = 0.66033148
# Iteration 263, loss = 0.66089369
# Iteration 264, loss = 0.66072295
# Iteration 265, loss = 0.66174798
# Iteration 266, loss = 0.66001268
# Iteration 267, loss = 0.65874319
# Iteration 268, loss = 0.66021007
# Iteration 269, loss = 0.65938217
# Iteration 270, loss = 0.66027532
# Iteration 271, loss = 0.65879867
# Iteration 272, loss = 0.65801607
# Iteration 273, loss = 0.65744652
# Iteration 274, loss = 0.65763791
# Iteration 275, loss = 0.66017667
# Iteration 276, loss = 0.65863170
# Iteration 277, loss = 0.65807702
# Iteration 278, loss = 0.65435165
# Iteration 279, loss = 0.65750714
# Iteration 280, loss = 0.65868271
# Iteration 281, loss = 0.65560982
# Iteration 282, loss = 0.65527617
# Iteration 283, loss = 0.65607191
# Iteration 284, loss = 0.65654297
# Iteration 285, loss = 0.65679808
# Iteration 286, loss = 0.65767824
# Iteration 287, loss = 0.65838252
# Iteration 288, loss = 0.65540158
# Iteration 289, loss = 0.65465212
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#   model  accuracy  precision  recall     f1
# 0   MLP    0.4918     0.4654  0.4918  0.476

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_gm.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.5562     0.4932  0.5562  0.5097
# 1   KNN    0.4995     0.4606  0.4995  0.4744
# 2    DT    0.4296     0.4424  0.4296  0.4351
# 3   SVM    0.2608     0.4459  0.2608  0.2883
# 4   MLP    0.4918     0.4654  0.4918  0.4760
