# %% [markdown]
# # TRTR Dataset A - Diabetes

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home directory of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TRAIN DATASETS/A_Diabetes_Data_Real_Train.csv')
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                      'A1Cresult','change','diabetesMed','readmitted']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0          81844290        94788  Female  [70-80)                 1
# 1         396159158    135023315    Male  [50-60)                 1
# 2          31258956     18397782    Male  [80-90)                 1
# 3         210691074     67509558    Male  [80-90)                 1
# 4         104902980     23272362  Female  [70-80)                 1
# ...             ...          ...     ...      ...               ...
# 81407      31296060      3344202    Male  [70-80)                 1
# 81408     159139902     93611655    Male  [60-70)                 5
# 81409     232191828     85600899    Male  [70-80)                 3
# 81410       6740700      8208234  Female  [60-70)                 6
# 81411      60115668     77943780  Female  [40-50)                 6
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   7                 4
# 1                            1                   7                 1
# 2                            1                   7                 4
# 3                            3                   7                 3
# 4                           11                   7                11
# ...                        ...                 ...               ...
# 81407                        1                   7                 2
# 81408                        1                   1                 5
# 81409                        3                   1                 3
# 81410                       25                   7                12
# 81411                        1                  17                 1
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      48               0               11                  0
# 1                      42               0                5                  0
# 2                      44               0               10                  0
# 3                      54               0                8                  0
# 4                      35               3               23                  0
# ...                   ...             ...              ...                ...
# 81407                  35               0               12                  0
# 81408                  63               2               23                  0
# 81409                  55               1               33                  0
# 81410                  77               2               21                  0
# 81411                   2               5               17                  0
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     0                 0                 9          None
# 1                     0                 0                 6          None
# 2                     0                 0                 7          None
# 3                     0                 0                 8          None
# 4                     0                 1                 8          None
# ...                 ...               ...               ...           ...
# 81407                 0                 0                 9          None
# 81408                 0                 0                 9          None
# 81409                 0                 0                 9          None
# 81410                 0                 0                 9          None
# 81411                 0                 0                 7          None
#
#       A1Cresult change diabetesMed readmitted
# 0          Norm     No          No         NO
# 1          None     No          No        >30
# 2          None     No         Yes         NO
# 3          None     Ch         Yes         NO
# 4          None     No          No         NO
# ...         ...    ...         ...        ...
# 81407      None     No          No        >30
# 81408      None     Ch         Yes        <30
# 81409      None     Ch         Yes         NO
# 81410      None     Ch         Yes        >30
# 81411      None     Ch         Yes         NO
#
# [81412 rows x 20 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/A_Diabetes_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0         110939484     19274094  Female  [70-80)                 1
# 1         170328306     65634327    Male  [50-60)                 1
# 2         245688426    100657359  Female  [60-70)                 3
# 3         150826224     83144448    Male  [30-40)                 2
# 4         135993852     65234214  Female  [60-70)                 1
# ...             ...          ...     ...      ...               ...
# 20349      61022328     93447369    Male  [80-90)                 1
# 20350     189128682     97296336    Male  [40-50)                 3
# 20351     251922018     84358062  Female  [70-80)                 1
# 20352     214461468     98468460    Male  [70-80)                 2
# 20353     128407860     42489621    Male  [80-90)                 3
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   6                11
# 1                            1                   1                 1
# 2                            6                   1                 4
# 3                            1                   1                12
# 4                            2                   7                 1
# ...                        ...                 ...               ...
# 20349                        1                   7                 6
# 20350                        1                   1                 2
# 20351                        1                   7                 9
# 20352                        1                   7                 2
# 20353                        1                   1                 7
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      68               0               20                  0
# 1                      20               0                7                  0
# 2                      21               3               23                  1
# 3                      28               0               19                  0
# 4                      21               0                6                  0
# ...                   ...             ...              ...                ...
# 20349                  51               1               17                  0
# 20350                  49               1               16                  0
# 20351                  41               2               17                  3
# 20352                  22               0                5                  0
# 20353                  16               4               14                  0
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     0                 0                 5          None
# 1                     0                 0                 8          None
# 2                     0                 2                 7          None
# 3                     0                 1                 7          None
# 4                     0                 0                 7          None
# ...                 ...               ...               ...           ...
# 20349                 0                 0                 8          None
# 20350                 0                 2                 9          None
# 20351                 0                 0                 9          None
# 20352                 0                 0                 7          None
# 20353                 0                 0                 9          None
#
#       A1Cresult change diabetesMed readmitted
# 0          None     No         Yes         NO
# 1          None     No         Yes         NO
# 2          None     No         Yes         NO
# 3          None     No         Yes        >30
# 4          None     No         Yes        <30
# ...         ...    ...         ...        ...
# 20349      None     No         Yes        <30
# 20350      None     Ch         Yes        <30
# 20351      None     No         Yes        >30
# 20352      None     No         Yes        >30
# 20353      None     No         Yes         NO
#
# [20354 rows x 20 columns]

# %%
target = 'readmitted'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (81412, 20)
# readmitted
# <30     9072
# >30    28428
# NO     43912
# dtype: int64
# #####################################
# Test data
# (20354, 20)
# readmitted
# <30     2285
# >30     7117
# NO     10952
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'readmitted'
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                    'A1Cresult','change','diabetesMed']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array(range(3)), np.array(range(10)), np.array(range(9)), np.array(range(29)), np.array(range(21)), 
                np.array(range(4)), np.array(range(4)), np.array(range(2)), np.array(range(2))]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((81412, 94), (81412,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((20354, 94), (20354,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    7.9s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.3s finished
#   model  accuracy  precision  recall      f1
# 0    RF    0.5912     0.5562  0.5912  0.5498

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN     0.548     0.5136   0.548  0.5211

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.4842     0.4873  0.4842  0.4857

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.2752     0.4189  0.2752  0.2942

# %% [markdown]
# Iteration 236, loss = 0.60705990
# Iteration 237, loss = 0.60790654
# Iteration 238, loss = 0.60824464
# Iteration 239, loss = 0.60670303
# Iteration 240, loss = 0.60702275
# Iteration 241, loss = 0.60739378
# Iteration 242, loss = 0.60758028
# Iteration 243, loss = 0.60652998
# Iteration 244, loss = 0.60813304
# Iteration 245, loss = 0.60539299
# Iteration 246, loss = 0.60632270
# Iteration 247, loss = 0.60362622
# Iteration 248, loss = 0.60608091
# Iteration 249, loss = 0.60491843
# Iteration 250, loss = 0.60504524
# Iteration 251, loss = 0.60560730
# Iteration 252, loss = 0.60505414
# Iteration 253, loss = 0.60474781
# Iteration 254, loss = 0.60342141
# Iteration 255, loss = 0.60508484
# Iteration 256, loss = 0.60545939
# Iteration 257, loss = 0.60388044
# Iteration 258, loss = 0.60224786
# Iteration 259, loss = 0.60256769
# Iteration 260, loss = 0.60222927
# Iteration 261, loss = 0.60240631
# Iteration 262, loss = 0.60314721
# Iteration 263, loss = 0.60202541
# Iteration 264, loss = 0.60127324
# Iteration 265, loss = 0.60043244
# Iteration 266, loss = 0.60049629
# Iteration 267, loss = 0.60484179
# Iteration 268, loss = 0.60009518
# Iteration 269, loss = 0.60175923
# Iteration 270, loss = 0.59895445
# Iteration 271, loss = 0.59810480
# Iteration 272, loss = 0.59887336
# Iteration 273, loss = 0.60223678
# Iteration 274, loss = 0.60024543
# Iteration 275, loss = 0.59975017
# Iteration 276, loss = 0.59976173
# Iteration 277, loss = 0.59890908
# Iteration 278, loss = 0.59778953
# Iteration 279, loss = 0.59822920
# Iteration 280, loss = 0.59653968
# Iteration 281, loss = 0.59835272
# Iteration 282, loss = 0.59838738
# Iteration 283, loss = 0.59765808
# Iteration 284, loss = 0.59919250
# Iteration 285, loss = 0.59736527
# Iteration 286, loss = 0.59770293
# Iteration 287, loss = 0.59633005
# Iteration 288, loss = 0.59718606
# Iteration 289, loss = 0.59635851
# Iteration 290, loss = 0.59620084
# Iteration 291, loss = 0.59827341
# Iteration 292, loss = 0.59532634
# Iteration 293, loss = 0.59610813
# Iteration 294, loss = 0.59739935
# Iteration 295, loss = 0.59438610
# Iteration 296, loss = 0.59683791
# Iteration 297, loss = 0.59753662
# Iteration 298, loss = 0.59309535
# Iteration 299, loss = 0.59537513
# Iteration 300, loss = 0.59516127
#   model  accuracy  precision  recall      f1
# 0   MLP    0.5283     0.5033  0.5283  0.5133

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_real.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.5912     0.5562  0.5912  0.5498
# 1   KNN    0.5480     0.5136  0.5480  0.5211
# 2    DT    0.4842     0.4873  0.4842  0.4857
# 3   SVM    0.2752     0.4189  0.2752  0.2942
# 4   MLP    0.5283     0.5033  0.5283  0.5133
