# %% [markdown]
# # TSTR WGANGP Dataset A - Diabetes

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home directory of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'SYNTHETIC DATASETS/WGANGP/A_Diabetes_Data_Synthetic_WGANGP.csv')
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                      'A1Cresult','change','diabetesMed','readmitted']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0         160291792     30203270  Female  [60-70)                 5
# 1         150234576     23529820  Female  [60-70)                 5
# 2         157173424     32108070  Female  [60-70)                 5
# 3         170411776     42212280    Male  [60-70)                 5
# 4         162151744     32820374  Female  [60-70)                 5
# ...             ...          ...     ...      ...               ...
# 81407     157678000     37311180  Female  [60-70)                 5
# 81408     150013616     62489392    Male  [60-70)                 2
# 81409     102509624      9322925    Male  [60-70)                 3
# 81410     154289120     29546988  Female  [60-70)                 5
# 81411     152470064     40726996    Male  [60-70)                 5
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   1                 2
# 1                            1                   1                 1
# 2                            1                   1                 2
# 3                            1                   1                 2
# 4                            1                   1                 2
# ...                        ...                 ...               ...
# 81407                        1                   1                 3
# 81408                        1                   7                 6
# 81409                        1                   1                 3
# 81410                        1                   1                 2
# 81411                        1                  17                 4
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      30               0               15                  1
# 1                      24               0               15                  2
# 2                      30               1               16                  1
# 3                      33               1               15                  0
# 4                      34               0               15                  1
# ...                   ...             ...              ...                ...
# 81407                  35               0               15                  1
# 81408                  61               2               19                  0
# 81409                  36               1               18                  0
# 81410                  27               1               16                  2
# 81411                  28               1               16                  0
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     1                 1                 6          None
# 1                     2                 2                 5          None
# 2                     1                 1                 6          None
# 3                     1                 1                 7          None
# 4                     1                 1                 6          None
# ...                 ...               ...               ...           ...
# 81407                 1                 1                 6          None
# 81408                 0                 1                 8          None
# 81409                 0                 0                 7          None
# 81410                 2                 2                 5          None
# 81411                 0                 0                 7          None
#
#       A1Cresult change diabetesMed readmitted
# 0          None     Ch         Yes        >30
# 1          None     Ch         Yes        >30
# 2          None     Ch         Yes        >30
# 3          None     Ch         Yes         NO
# 4          None     Ch         Yes        >30
# ...         ...    ...         ...        ...
# 81407      None     Ch         Yes        >30
# 81408      None     Ch         Yes        <30
# 81409      None     Ch         Yes         NO
# 81410      None     Ch         Yes        >30
# 81411      None     Ch         Yes         NO
#
# [81412 rows x 20 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/A_Diabetes_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#        encounter_id  patient_nbr  gender      age admission_type_id  \
# 0         110939484     19274094  Female  [70-80)                 1
# 1         170328306     65634327    Male  [50-60)                 1
# 2         245688426    100657359  Female  [60-70)                 3
# 3         150826224     83144448    Male  [30-40)                 2
# 4         135993852     65234214  Female  [60-70)                 1
# ...             ...          ...     ...      ...               ...
# 20349      61022328     93447369    Male  [80-90)                 1
# 20350     189128682     97296336    Male  [40-50)                 3
# 20351     251922018     84358062  Female  [70-80)                 1
# 20352     214461468     98468460    Male  [70-80)                 2
# 20353     128407860     42489621    Male  [80-90)                 3
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0                            1                   6                11
# 1                            1                   1                 1
# 2                            6                   1                 4
# 3                            1                   1                12
# 4                            2                   7                 1
# ...                        ...                 ...               ...
# 20349                        1                   7                 6
# 20350                        1                   1                 2
# 20351                        1                   7                 9
# 20352                        1                   7                 2
# 20353                        1                   1                 7
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      68               0               20                  0
# 1                      20               0                7                  0
# 2                      21               3               23                  1
# 3                      28               0               19                  0
# 4                      21               0                6                  0
# ...                   ...             ...              ...                ...
# 20349                  51               1               17                  0
# 20350                  49               1               16                  0
# 20351                  41               2               17                  3
# 20352                  22               0                5                  0
# 20353                  16               4               14                  0
#
#        number_emergency  number_inpatient  number_diagnoses max_glu_serum  \
# 0                     0                 0                 5          None
# 1                     0                 0                 8          None
# 2                     0                 2                 7          None
# 3                     0                 1                 7          None
# 4                     0                 0                 7          None
# ...                 ...               ...               ...           ...
# 20349                 0                 0                 8          None
# 20350                 0                 2                 9          None
# 20351                 0                 0                 9          None
# 20352                 0                 0                 7          None
# 20353                 0                 0                 9          None
#
#       A1Cresult change diabetesMed readmitted
# 0          None     No         Yes         NO
# 1          None     No         Yes         NO
# 2          None     No         Yes         NO
# 3          None     No         Yes        >30
# 4          None     No         Yes        <30
# ...         ...    ...         ...        ...
# 20349      None     No         Yes        <30
# 20350      None     Ch         Yes        <30
# 20351      None     No         Yes        >30
# 20352      None     No         Yes        >30
# 20353      None     No         Yes         NO
#
# [20354 rows x 20 columns]

# %%
target = 'readmitted'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (81412, 20)
# readmitted
# <30    14552
# >30    42112
# NO     24748
# dtype: int64
# #####################################
# Test data
# (20354, 20)
# readmitted
# <30     2285
# >30     7117
# NO     10952
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'readmitted'
categorical_columns = ['gender','age','admission_type_id','discharge_disposition_id','admission_source_id','max_glu_serum',
                    'A1Cresult','change','diabetesMed']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array(range(3)), np.array(range(10)), np.array(range(9)), np.array(range(29)), np.array(range(21)), 
                np.array(range(4)), np.array(range(4)), np.array(range(2)), np.array(range(2))]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((81412, 94), (81412,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((20354, 94), (20354,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    4.3s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.1s finished
#   model  accuracy  precision  recall     f1
# 0    RF    0.4917     0.4541  0.4917  0.461

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.4248     0.4528  0.4248  0.4316

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.4208     0.4414  0.4208  0.4289

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
svm_results['model'] = svm_results['model'].replace(['MLP'],'SVM')
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.2249     0.4742  0.2249  0.2386

# %% [markdown]
# ## 8. Train and evaluate Multilayer Perceptron Classifier

# %%
mlp_results = train_evaluate_model('MLP', x_train, y_train, x_test, y_test)
results = results.append(mlp_results, ignore_index=True)
mlp_results
# Out:
# Iteration 1, loss = 0.16884682
# Iteration 2, loss = 0.11760759
# Iteration 3, loss = 0.11087512
# Iteration 4, loss = 0.10780863
# Iteration 5, loss = 0.10604144
# Iteration 6, loss = 0.10372577
# Iteration 7, loss = 0.10244279
# Iteration 8, loss = 0.10085110
# Iteration 9, loss = 0.10068159
# Iteration 10, loss = 0.09907646
# Iteration 11, loss = 0.09849422
# Iteration 12, loss = 0.09752210
# Iteration 13, loss = 0.09802663
# Iteration 14, loss = 0.09621681
# Iteration 15, loss = 0.09506780
# Iteration 16, loss = 0.09471739
# Iteration 17, loss = 0.09493640
# Iteration 194, loss = 0.06096646
# Iteration 195, loss = 0.06154280
# Iteration 196, loss = 0.06224314
# Iteration 197, loss = 0.06027165
# Iteration 198, loss = 0.06135558
# Iteration 199, loss = 0.06134351
# Iteration 200, loss = 0.06105118
# Iteration 201, loss = 0.06092726
# Iteration 202, loss = 0.06085876
# Iteration 203, loss = 0.06040292
# Iteration 204, loss = 0.06052297
# Iteration 205, loss = 0.06099803
# Iteration 206, loss = 0.06073520
# Iteration 207, loss = 0.06056641
# Iteration 208, loss = 0.05985769
# Iteration 209, loss = 0.05935794
# Iteration 210, loss = 0.06012419
# Iteration 211, loss = 0.06098135
# Iteration 212, loss = 0.06015796
# Iteration 213, loss = 0.06187713
# Iteration 214, loss = 0.06007996
# Iteration 215, loss = 0.05899432
# Iteration 216, loss = 0.05900739
# Iteration 217, loss = 0.06009527
# Iteration 218, loss = 0.05927012
# Iteration 219, loss = 0.05917751
# Iteration 220, loss = 0.05890830
# Iteration 221, loss = 0.05845408
# Iteration 222, loss = 0.05903195
# Iteration 223, loss = 0.05860681
# Iteration 224, loss = 0.06009144
# Iteration 225, loss = 0.05875752
# Iteration 226, loss = 0.05844925
# Iteration 227, loss = 0.05858625
# Iteration 228, loss = 0.05842384
# Iteration 229, loss = 0.06052187
# Iteration 230, loss = 0.05986945
# Iteration 231, loss = 0.05865986
# Iteration 232, loss = 0.05807712
# Iteration 233, loss = 0.05790273
# Iteration 234, loss = 0.05798713
# Iteration 235, loss = 0.05841314
# Iteration 236, loss = 0.05720152
# Iteration 237, loss = 0.05794359
# Iteration 238, loss = 0.05799226
# Iteration 239, loss = 0.05894730
# Iteration 240, loss = 0.05755885
# Iteration 241, loss = 0.05862449
# Iteration 242, loss = 0.05772243
# Iteration 243, loss = 0.05822016
# Iteration 244, loss = 0.05747785
# Iteration 245, loss = 0.05720019
# Iteration 246, loss = 0.05787932
# Iteration 247, loss = 0.05663695
# Iteration 248, loss = 0.05631895
# Iteration 249, loss = 0.05678419
# Iteration 250, loss = 0.06008359
# Iteration 251, loss = 0.05877687
# Iteration 252, loss = 0.05632434
# Iteration 253, loss = 0.05803568
# Iteration 254, loss = 0.05577612
# Iteration 255, loss = 0.05558973
# Iteration 256, loss = 0.05742623
# Iteration 257, loss = 0.05589422
# Iteration 258, loss = 0.05609675
# Iteration 259, loss = 0.05628966
# Iteration 260, loss = 0.05680257
# Iteration 261, loss = 0.05613167
# Iteration 262, loss = 0.05656384
# Iteration 263, loss = 0.05551431
# Iteration 264, loss = 0.05679815
# Iteration 265, loss = 0.05567291
# Iteration 266, loss = 0.05557031
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#   model  accuracy  precision  recall      f1
# 0   MLP    0.4685     0.4333  0.4685  0.4283

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_wgangp.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.4917     0.4541  0.4917  0.4610
# 1   KNN    0.4248     0.4528  0.4248  0.4316
# 2    DT    0.4208     0.4414  0.4208  0.4289
# 3   SVM    0.2249     0.4742  0.2249  0.2386
# 4   MLP    0.4685     0.4333  0.4685  0.4283
