# %%
#Load libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from ctgan import CTGANSynthesizer

# %%
HOME_PATH = '' #home path of the project
TRAIN_FILE = 'REAL DATASETS/TRAIN DATASETS/C_Obesity_Data_Real_Train.csv'
SYNTHETIC_FILE = 'SYNTHETIC DATASETS/CTGAN/C_Obesity_Data_Synthetic_CTGAN.csv'

# %% [markdown]
# ## 1. Load the dataset

# %%
real_data = pd.read_csv(HOME_PATH + TRAIN_FILE)
real_data
# Out:
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  \
# 0     Female   21    1.63   60.00                            yes  yes
# 1     Female   21    1.75  133.62                            yes  yes
# 2     Female   23    1.66   82.60                            yes  yes
# 3     Female   22    1.59   44.24                             no   no
# 4       Male   26    1.81  106.04                            yes  yes
# ...      ...  ...     ...     ...                            ...  ...
# 1683    Male   32    1.75  120.10                            yes  yes
# 1684    Male   23    1.72   81.67                            yes  yes
# 1685  Female   23    1.65   80.00                            yes  yes
# 1686  Female   23    1.63   84.50                            yes  yes
# 1687    Male   20    1.82   85.00                            yes  yes
#
#           FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF       TUE  \
# ...

# %%
real_data.dtypes
# Out:
# Gender                             object
# Age                                 int64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# Obesity_level                      object
# dtype: object

# %%
discrete_columns = ['Gender','family_history_with_overweight','FAVC','FCVC','CAEC','SMOKE','SCC','CALC','MTRANS','Obesity_level']
discrete_columns
# Out:
# ['Gender',
#  'family_history_with_overweight',
#  'FAVC',
#  'FCVC',
#  'CAEC',
#  'SMOKE',
#  'SCC',
#  'CALC',
#  'MTRANS',
#  'Obesity_level']

# %%
ctgan = CTGANSynthesizer()
ctgan.fit(real_data, discrete_columns)

# %%
synthetic_data = ctgan.sample(len(real_data))
synthetic_data
# Out:
#       Gender  Age    Height     Weight family_history_with_overweight FAVC  \
# 0       Male   22  1.615909  70.916647                             no  yes
# 1       Male   19  1.627690  38.963229                            yes  yes
# 2     Female   23  1.651837  39.270701                            yes   no
# 3       Male   39  1.599153  53.385542                            yes  yes
# 4       Male   25  1.772736  37.032741                            yes  yes
# ...      ...  ...       ...        ...                            ...  ...
# 1683    Male   24  1.655055  59.147433                            yes  yes
# 1684    Male   26  1.471980  39.273362                            yes  yes
# 1685    Male   26  1.757607  73.089889                             no  yes
# 1686  Female   25  1.843430  88.362564                             no  yes
# 1687    Male   22  1.661903  57.925314                             no  yes
#
# ...

# %%
synthetic_data.to_csv(HOME_PATH + SYNTHETIC_FILE, index = False)
