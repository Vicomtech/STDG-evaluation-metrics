# %% [markdown]
# # TSTR GM Dataset C - Obesity

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home path of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'SYNTHETIC DATASETS/GM/C_Obesity_Data_Synthetic_GM.csv')
categorical_columns = ['Gender','family_history_with_overweight','FAVC','CAEC','SMOKE','SCC','CALC','MTRANS','Obesity_level']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#       Gender  Age    Height      Weight family_history_with_overweight FAVC  \
# 0     Female   21  1.736983   96.575084                            yes  yes
# 1       Male   27  1.791849  132.568140                            yes  yes
# 2       Male   16  1.849836   80.521419                             no  yes
# 3       Male   20  1.753469  107.888290                            yes  yes
# 4     Female   33  1.616082  112.720873                            yes  yes
# ...      ...  ...       ...         ...                            ...  ...
# 1683    Male   23  1.729979  107.686391                            yes  yes
# 1684    Male   24  1.722470  122.682563                            yes  yes
# 1685  Female   26  1.761826   88.618928                            yes  yes
# 1686  Female   21  1.508331  102.850821                            yes  yes
# 1687  Female   25  1.587326  131.071269                            yes  yes
#
#           FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 0     3.043926  3.229494   Sometimes    no  2.767918  no  0.559224  0.723408
# 1     2.743510  3.213367   Sometimes    no  2.543950  no -0.718087  0.050567
# 2     2.474037  2.287594  Frequently    no  3.005978  no  0.120772  1.338905
# 3     2.575027  2.686841   Sometimes    no  2.198808  no  1.113582  0.739439
# 4     2.779278  1.335992   Sometimes    no  2.765885  no  1.447929  1.321864
# ...        ...       ...         ...   ...       ...  ..       ...       ...
# 1683  3.038139  3.429195   Sometimes    no  1.447293  no  0.157166  0.764616
# 1684  2.556549  3.763153   Sometimes    no  2.444046  no  2.250645  0.188289
# 1685  2.240721  3.604517   Sometimes    no  2.886618  no  0.781996  0.615303
# 1686  2.048591  1.967142   Sometimes    no  2.308040  no -0.629877 -0.509730
# 1687  2.548532  1.763349   Sometimes    no  1.135346  no  1.327956  1.790538
#
#            CALC                 MTRANS        Obesity_level
# 0     Sometimes  Public_Transportation  Insufficient_Weight
# 1     Sometimes  Public_Transportation      Obesity_Type_II
# 2     Sometimes  Public_Transportation   Overweight_Level_I
# 3     Sometimes  Public_Transportation  Overweight_Level_II
# 4     Sometimes  Public_Transportation       Obesity_Type_I
# ...         ...                    ...                  ...
# 1683  Sometimes             Automobile     Obesity_Type_III
# 1684  Sometimes  Public_Transportation     Obesity_Type_III
# 1685  Sometimes             Automobile       Obesity_Type_I
# 1686  Sometimes  Public_Transportation       Obesity_Type_I
# 1687         no  Public_Transportation     Obesity_Type_III
#
# [1688 rows x 17 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/C_Obesity_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#      Gender  Age  Height  Weight family_history_with_overweight FAVC  \
# 0    Female   20    1.76   53.70                            yes  yes
# 1    Female   26    1.62  111.00                            yes  yes
# 2      Male   18    1.85   60.00                            yes  yes
# 3    Female   21    1.52   42.00                             no  yes
# 4      Male   22    1.75   74.00                            yes   no
# ..      ...  ...     ...     ...                            ...  ...
# 418    Male   19    1.80   87.00                            yes  yes
# 419    Male   31    1.65  101.14                            yes  yes
# 420    Male   19    1.85   65.00                            yes   no
# 421    Male   29    1.76  113.50                            yes  yes
# 422    Male   19    1.70   79.68                            yes   no
#
#          FCVC       NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0    2.000000  3.891994  Frequently    no  1.863930   no  2.870127  2.000000
# 1    3.000000  3.000000   Sometimes    no  2.704315   no  0.000000  0.322666
# 2    3.000000  4.000000   Sometimes    no  2.000000  yes  2.000000  0.000000
# 3    3.000000  1.000000  Frequently    no  1.000000   no  0.000000  0.000000
# 4    2.000000  3.000000   Sometimes    no  2.000000   no  1.000000  2.000000
# ..        ...       ...         ...   ...       ...  ...       ...       ...
# 418  2.000000  4.000000   Sometimes    no  2.000000   no  2.000000  1.000000
# 419  2.913452  2.269799   Sometimes    no  1.000000   no  1.889937  0.378818
# 420  2.000000  3.000000   Sometimes    no  3.000000   no  2.000000  1.000000
# 421  2.320201  3.000000   Sometimes    no  2.164784   no  0.000000  1.465479
# 422  2.735297  2.157164   Sometimes    no  1.087166   no  0.110174  0.003695
#
#           CALC                 MTRANS        Obesity_level
# 0           no  Public_Transportation  Insufficient_Weight
# 1    Sometimes  Public_Transportation     Obesity_Type_III
# 2    Sometimes             Automobile  Insufficient_Weight
# 3    Sometimes  Public_Transportation  Insufficient_Weight
# 4    Sometimes                   Bike        Normal_Weight
# ..         ...                    ...                  ...
# 418  Sometimes  Public_Transportation   Overweight_Level_I
# 419         no  Public_Transportation      Obesity_Type_II
# 420  Sometimes                   Bike        Normal_Weight
# 421  Sometimes             Automobile      Obesity_Type_II
# 422         no  Public_Transportation  Overweight_Level_II
#
# [423 rows x 17 columns]

# %%
target = 'Obesity_level'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (1688, 17)
# Obesity_level
# Insufficient_Weight    221
# Normal_Weight          210
# Obesity_Type_I         266
# Obesity_Type_II        250
# Obesity_Type_III       290
# Overweight_Level_I     232
# Overweight_Level_II    219
# dtype: int64
# #####################################
# Test data
# (423, 17)
# Obesity_level
# Insufficient_Weight    56
# Normal_Weight          62
# Obesity_Type_I         78
# Obesity_Type_II        58
# Obesity_Type_III       63
# Overweight_Level_I     56
# Overweight_Level_II    50
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'Obesity_level'
categorical_columns = ['Gender','family_history_with_overweight','FAVC','CAEC','SMOKE','SCC','CALC','MTRANS']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array([0, 1]), np.array([0, 1]), np.array([0, 1]), np.array([0, 1, 2, 3]), np.array([0, 1]), 
              np.array([0, 1]), np.array([0, 1, 2, 3]), np.array([0, 1, 2, 3, 4])]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((1688, 31), (1688,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((423, 31), (423,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.0s finished
#   model  accuracy  precision  recall      f1
# 0    RF    0.4752     0.4486  0.4752  0.4472

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.4255     0.4021  0.4255  0.4061

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.3972      0.395  0.3972  0.3926

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
# Iteration 235, loss = 0.12781541
# Iteration 236, loss = 0.12623955
# Iteration 237, loss = 0.12446437
# Iteration 238, loss = 0.12334102
# Iteration 239, loss = 0.12147676
# Iteration 240, loss = 0.11904073
# Iteration 241, loss = 0.11631677
# Iteration 242, loss = 0.11690826
# Iteration 243, loss = 0.11518406
# Iteration 244, loss = 0.11461134
# Iteration 245, loss = 0.11204341
# Iteration 246, loss = 0.11210660
# Iteration 247, loss = 0.10952231
# Iteration 248, loss = 0.10735699
# Iteration 249, loss = 0.10491967
# Iteration 250, loss = 0.10311617
# Iteration 251, loss = 0.10579442
# Iteration 252, loss = 0.10912895
# Iteration 253, loss = 0.10150004
# Iteration 254, loss = 0.09907150
# Iteration 255, loss = 0.09711618
# Iteration 256, loss = 0.09727398
# Iteration 257, loss = 0.09791708
# Iteration 258, loss = 0.09284522
# Iteration 259, loss = 0.09195249
# Iteration 260, loss = 0.08902233
# Iteration 261, loss = 0.08838016
# Iteration 262, loss = 0.08555536
# Iteration 263, loss = 0.08810255
# Iteration 264, loss = 0.09243935
# Iteration 265, loss = 0.09073968
# Iteration 266, loss = 0.08568783
# Iteration 267, loss = 0.08508748
# Iteration 268, loss = 0.08831792
# Iteration 269, loss = 0.08741168
# Iteration 270, loss = 0.08216484
# Iteration 271, loss = 0.07845640
# Iteration 272, loss = 0.07717620
# Iteration 273, loss = 0.07684351
# Iteration 274, loss = 0.07693324
# Iteration 275, loss = 0.07962689
# Iteration 276, loss = 0.07427143
# Iteration 277, loss = 0.07452460
# Iteration 278, loss = 0.07053200
# Iteration 279, loss = 0.06837415
# Iteration 280, loss = 0.06769518
# Iteration 281, loss = 0.06662430
# Iteration 282, loss = 0.06693907
# Iteration 283, loss = 0.06500133
# Iteration 284, loss = 0.06591338
# Iteration 285, loss = 0.06449333
# Iteration 286, loss = 0.06319448
# Iteration 287, loss = 0.06295757
# Iteration 288, loss = 0.06459518
# Iteration 289, loss = 0.06500939
# Iteration 290, loss = 0.06214245
# Iteration 291, loss = 0.06337656
# Iteration 292, loss = 0.06145254
# Iteration 293, loss = 0.05973622
# Iteration 294, loss = 0.05755982
# Iteration 295, loss = 0.05512376
# Iteration 296, loss = 0.05599797
# Iteration 297, loss = 0.05651124
# Iteration 298, loss = 0.05495199
# Iteration 299, loss = 0.05317735
# Iteration 300, loss = 0.05073335
#   model  accuracy  precision  recall      f1
# 0   MLP    0.4043     0.3893  0.4043  0.3947

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_gm.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.4752     0.4486  0.4752  0.4472
# 1   KNN    0.4255     0.4021  0.4255  0.4061
# 2    DT    0.3972     0.3950  0.3972  0.3926
# 3   SVM    0.2884     0.2830  0.2884  0.2830
# 4   MLP    0.4043     0.3893  0.4043  0.3947
