# %% [markdown]
# # TSTR SDV Dataset C - Obesity

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home path of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'SYNTHETIC DATASETS/SDV/C_Obesity_Data_Synthetic_SDV.csv')
categorical_columns = ['Gender','family_history_with_overweight','FAVC','CAEC','SMOKE','SCC','CALC','MTRANS','Obesity_level']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  \
# 0       Male   28    1.76  123.43                            yes  yes
# 1       Male   12    1.69   40.75                            yes  yes
# 2     Female   18    1.63   94.78                            yes  yes
# 3       Male   21    1.82  137.00                             no  yes
# 4     Female   38    1.65   84.02                            yes  yes
# ...      ...  ...     ...     ...                            ...  ...
# 1683    Male   31    1.48   76.02                            yes  yes
# 1684  Female   21    1.67   45.28                            yes  yes
# 1685    Male   32    1.69  103.85                            yes  yes
# 1686    Male   22    1.77  115.65                            yes  yes
# 1687  Female   30    1.56   80.21                            yes  yes
#
#           FCVC       NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 0     3.205596  2.903116  Sometimes    no  1.904073  no  0.448286  0.313930
# 1     2.239509  2.653353  Sometimes    no  2.042313  no  0.645014  0.601065
# 2     3.094983  3.169795  Sometimes    no  2.692556  no  1.037283  0.856946
# 3     2.095592  3.177185  Sometimes    no  2.276122  no  1.221715  0.845391
# 4     2.726584  1.015046  Sometimes    no  0.278486  no  1.055731  0.248985
# ...        ...       ...        ...   ...       ...  ..       ...       ...
# 1683  2.602491  3.355760  Sometimes    no  2.240679  no  1.903530  0.172436
# 1684  2.534703  3.542202  Sometimes    no  1.935781  no -0.184959  0.306923
# 1685  2.682470  2.334944  Sometimes    no  3.093748  no  1.181994  0.758202
# 1686  3.076754  3.583925  Sometimes    no  2.792898  no  1.703388  1.141771
# 1687  2.743709  3.437653  Sometimes    no  2.086823  no  0.345362  0.778831
#
#            CALC                 MTRANS        Obesity_level
# 0     Sometimes  Public_Transportation      Obesity_Type_II
# 1            no  Public_Transportation   Overweight_Level_I
# 2     Sometimes  Public_Transportation   Overweight_Level_I
# 3     Sometimes  Public_Transportation       Obesity_Type_I
# 4            no  Public_Transportation      Obesity_Type_II
# ...         ...                    ...                  ...
# 1683  Sometimes  Public_Transportation  Overweight_Level_II
# 1684  Sometimes  Public_Transportation        Normal_Weight
# 1685  Sometimes  Public_Transportation       Obesity_Type_I
# 1686  Sometimes  Public_Transportation      Obesity_Type_II
# 1687  Sometimes  Public_Transportation     Obesity_Type_III
#
# [1688 rows x 17 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/C_Obesity_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#      Gender  Age  Height  Weight family_history_with_overweight FAVC  \
# 0    Female   20    1.76   53.70                            yes  yes
# 1    Female   26    1.62  111.00                            yes  yes
# 2      Male   18    1.85   60.00                            yes  yes
# 3    Female   21    1.52   42.00                             no  yes
# 4      Male   22    1.75   74.00                            yes   no
# ..      ...  ...     ...     ...                            ...  ...
# 418    Male   19    1.80   87.00                            yes  yes
# 419    Male   31    1.65  101.14                            yes  yes
# 420    Male   19    1.85   65.00                            yes   no
# 421    Male   29    1.76  113.50                            yes  yes
# 422    Male   19    1.70   79.68                            yes   no
#
#          FCVC       NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0    2.000000  3.891994  Frequently    no  1.863930   no  2.870127  2.000000
# 1    3.000000  3.000000   Sometimes    no  2.704315   no  0.000000  0.322666
# 2    3.000000  4.000000   Sometimes    no  2.000000  yes  2.000000  0.000000
# 3    3.000000  1.000000  Frequently    no  1.000000   no  0.000000  0.000000
# 4    2.000000  3.000000   Sometimes    no  2.000000   no  1.000000  2.000000
# ..        ...       ...         ...   ...       ...  ...       ...       ...
# 418  2.000000  4.000000   Sometimes    no  2.000000   no  2.000000  1.000000
# 419  2.913452  2.269799   Sometimes    no  1.000000   no  1.889937  0.378818
# 420  2.000000  3.000000   Sometimes    no  3.000000   no  2.000000  1.000000
# 421  2.320201  3.000000   Sometimes    no  2.164784   no  0.000000  1.465479
# 422  2.735297  2.157164   Sometimes    no  1.087166   no  0.110174  0.003695
#
#           CALC                 MTRANS        Obesity_level
# 0           no  Public_Transportation  Insufficient_Weight
# 1    Sometimes  Public_Transportation     Obesity_Type_III
# 2    Sometimes             Automobile  Insufficient_Weight
# 3    Sometimes  Public_Transportation  Insufficient_Weight
# 4    Sometimes                   Bike        Normal_Weight
# ..         ...                    ...                  ...
# 418  Sometimes  Public_Transportation   Overweight_Level_I
# 419         no  Public_Transportation      Obesity_Type_II
# 420  Sometimes                   Bike        Normal_Weight
# 421  Sometimes             Automobile      Obesity_Type_II
# 422         no  Public_Transportation  Overweight_Level_II
#
# [423 rows x 17 columns]

# %%
target = 'Obesity_level'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (1688, 17)
# Obesity_level
# Insufficient_Weight    135
# Normal_Weight          203
# Obesity_Type_I         185
# Obesity_Type_II        311
# Obesity_Type_III       267
# Overweight_Level_I     297
# Overweight_Level_II    290
# dtype: int64
# #####################################
# Test data
# (423, 17)
# Obesity_level
# Insufficient_Weight    56
# Normal_Weight          62
# Obesity_Type_I         78
# Obesity_Type_II        58
# Obesity_Type_III       63
# Overweight_Level_I     56
# Overweight_Level_II    50
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'Obesity_level'
categorical_columns = ['Gender','family_history_with_overweight','FAVC','CAEC','SMOKE','SCC','CALC','MTRANS']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array([0, 1]), np.array([0, 1]), np.array([0, 1]), np.array([0, 1, 2, 3]), np.array([0, 1]), 
              np.array([0, 1]), np.array([0, 1, 2, 3]), np.array([0, 1, 2, 3, 4])]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((1688, 31), (1688,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((423, 31), (423,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.0s finished
#   model  accuracy  precision  recall     f1
# 0    RF    0.1702     0.2082  0.1702  0.175

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.1513     0.1667  0.1513  0.1502

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.1915     0.2394  0.1915  0.2069

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# Iteration 235, loss = 0.22152444
# Iteration 236, loss = 0.21854281
# Iteration 237, loss = 0.21379416
# Iteration 238, loss = 0.21094766
# Iteration 239, loss = 0.21042034
# Iteration 240, loss = 0.21180040
# Iteration 241, loss = 0.20798729
# Iteration 242, loss = 0.20035061
# Iteration 243, loss = 0.19777664
# Iteration 244, loss = 0.19762202
# Iteration 245, loss = 0.19857430
# Iteration 246, loss = 0.19430758
# Iteration 247, loss = 0.18818136
# Iteration 248, loss = 0.19359059
# Iteration 249, loss = 0.19279985
# Iteration 250, loss = 0.18738274
# Iteration 251, loss = 0.18290114
# Iteration 252, loss = 0.18092815
# Iteration 253, loss = 0.17377890
# Iteration 254, loss = 0.17935469
# Iteration 255, loss = 0.18123901
# Iteration 256, loss = 0.17457759
# Iteration 257, loss = 0.17664846
# Iteration 258, loss = 0.17538999
# Iteration 259, loss = 0.16886971
# Iteration 260, loss = 0.16644417
# Iteration 261, loss = 0.16430180
# Iteration 262, loss = 0.15759064
# Iteration 263, loss = 0.15475316
# Iteration 264, loss = 0.15299118
# Iteration 265, loss = 0.15405532
# Iteration 266, loss = 0.14842620
# Iteration 267, loss = 0.14912844
# Iteration 268, loss = 0.14859278
# Iteration 269, loss = 0.14519363
# Iteration 270, loss = 0.14122121
# Iteration 271, loss = 0.14060826
# Iteration 272, loss = 0.14153579
# Iteration 273, loss = 0.14011062
# Iteration 274, loss = 0.13897745
# Iteration 275, loss = 0.13869756
# Iteration 276, loss = 0.13703995
# Iteration 277, loss = 0.13669012
# Iteration 278, loss = 0.13218989
# Iteration 279, loss = 0.13245994
# Iteration 280, loss = 0.12945020
# Iteration 281, loss = 0.13206420
# Iteration 282, loss = 0.13079543
# Iteration 283, loss = 0.12695704
# Iteration 284, loss = 0.12378731
# Iteration 285, loss = 0.12677431
# Iteration 286, loss = 0.12520195
# Iteration 287, loss = 0.11991108
# Iteration 288, loss = 0.11732294
# Iteration 289, loss = 0.11367864
# Iteration 290, loss = 0.11220488
# Iteration 291, loss = 0.10948789
# Iteration 292, loss = 0.10853457
# Iteration 293, loss = 0.10716554
# Iteration 294, loss = 0.10724554
# Iteration 295, loss = 0.10154611
# Iteration 296, loss = 0.10026988
# Iteration 297, loss = 0.09849673
# Iteration 298, loss = 0.09852446
# Iteration 299, loss = 0.10081874
# Iteration 300, loss = 0.10026985
#   model  accuracy  precision  recall      f1
# 0   MLP    0.1939     0.1907  0.1939  0.1769

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_sdv.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.1702     0.2082  0.1702  0.1750
# 1   KNN    0.1513     0.1667  0.1513  0.1502
# 2    DT    0.1915     0.2394  0.1915  0.2069
# 3   SVM    0.1702     0.1973  0.1702  0.1665
# 4   MLP    0.1939     0.1907  0.1939  0.1769
