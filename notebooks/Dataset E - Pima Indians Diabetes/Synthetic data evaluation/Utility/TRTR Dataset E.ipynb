# %% [markdown]
# # TRTR Dataset E

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home path of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TRAIN DATASETS/E_PimaIndiansDiabetes_Real_Train.csv')
categorical_columns = ['Outcome']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              2       84              0              0        0   0.0
# 1              9      112             82             24        0  28.2
# 2              1      139             46             19       83  28.7
# 3              0      161             50              0        0  21.9
# 4              6      134             80             37      370  46.2
# ..           ...      ...            ...            ...      ...   ...
# 609            5      139             64             35      140  28.6
# 610            1       96            122              0        0  22.4
# 611           10      101             86             37        0  45.6
# 612            0      141              0              0        0  42.4
# 613            0      125             96              0        0  22.5
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.304   21       0
# 1                       1.282   50       1
# 2                       0.654   22       0
# 3                       0.254   65       0
# 4                       0.238   46       1
# ..                        ...  ...     ...
# 609                     0.411   26       0
# 610                     0.207   27       0
# 611                     1.136   38       1
# 612                     0.205   29       1
# 613                     0.262   21       0
#
# [614 rows x 9 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/E_PimaIndiansDiabetes_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6       98             58             33      190  34.0
# 1              2      112             75             32        0  35.7
# 2              2      108             64              0        0  30.8
# 3              8      107             80              0        0  24.6
# 4              7      136             90              0        0  29.9
# ..           ...      ...            ...            ...      ...   ...
# 149            9      165             88              0        0  30.4
# 150            1       77             56             30       56  33.3
# 151            8       95             72              0        0  36.8
# 152            2      146             70             38      360  28.0
# 153            8       74             70             40       49  35.3
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.430   43       0
# 1                       0.148   21       0
# 2                       0.158   21       0
# 3                       0.856   34       0
# 4                       0.210   50       0
# ..                        ...  ...     ...
# 149                     0.302   49       1
# 150                     1.251   24       0
# 151                     0.485   57       0
# 152                     0.337   29       1
# 153                     0.705   39       0
#
# [154 rows x 9 columns]

# %%
target = 'Outcome'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (614, 9)
# Outcome
# 0    401
# 1    213
# dtype: int64
# #####################################
# Test data
# (154, 9)
# Outcome
# 0    99
# 1    55
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'Outcome'
categorical_columns = None
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = None

data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((614, 8), (614,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((154, 8), (154,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.0s finished
#   model  accuracy  precision  recall      f1
# 0    RF    0.7338     0.7349  0.7338  0.7343

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.6883     0.6782  0.6883  0.6802

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.7792     0.7835  0.7792  0.7808

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall    f1
# 0   SVM     0.461     0.5452   0.461  0.46

# %% [markdown]
# ## 8. Train and evaluate Multilayer Perceptron Classifier

# %%
mlp_results = train_evaluate_model('MLP', x_train, y_train, x_test, y_test)
results = results.append(mlp_results, ignore_index=True)
mlp_results
# Out:
# Iteration 1, loss = 0.67894164
# Iteration 2, loss = 0.63957689
# Iteration 3, loss = 0.61049009
# Iteration 4, loss = 0.58593050
# Iteration 5, loss = 0.56227293
# Iteration 6, loss = 0.53861149
# Iteration 7, loss = 0.51577049
# Iteration 8, loss = 0.49566069
# Iteration 9, loss = 0.47839355
# Iteration 10, loss = 0.46719567
# Iteration 11, loss = 0.45778521
# Iteration 12, loss = 0.45115816
# Iteration 13, loss = 0.44815100
# Iteration 14, loss = 0.44945862
# Iteration 15, loss = 0.44392758
# Iteration 16, loss = 0.43576709
# Iteration 17, loss = 0.43164609
# Iteration 18, loss = 0.42800737
# Iteration 19, loss = 0.42477162
# Iteration 20, loss = 0.42101884
# Iteration 21, loss = 0.41910086
# Iteration 22, loss = 0.41647330
# Iteration 23, loss = 0.41436486
# Iteration 24, loss = 0.41134364
# Iteration 25, loss = 0.40767881
# Iteration 26, loss = 0.40581910
# Iteration 27, loss = 0.40550827
# Iteration 28, loss = 0.40384279
# Iteration 29, loss = 0.40008713
# Iteration 30, loss = 0.39903273
# Iteration 31, loss = 0.40192260
# Iteration 32, loss = 0.39762114
# Iteration 33, loss = 0.39405628
# Iteration 34, loss = 0.39228451
# Iteration 222, loss = 0.10649110
# Iteration 223, loss = 0.12422004
# Iteration 224, loss = 0.10553422
# Iteration 225, loss = 0.09257298
# Iteration 226, loss = 0.10757059
# Iteration 227, loss = 0.09203155
# Iteration 228, loss = 0.09588430
# Iteration 229, loss = 0.10308775
# Iteration 230, loss = 0.10066270
# Iteration 231, loss = 0.09447677
# Iteration 232, loss = 0.08020789
# Iteration 233, loss = 0.08251899
# Iteration 234, loss = 0.08728404
# Iteration 235, loss = 0.07857184
# Iteration 236, loss = 0.08189668
# Iteration 237, loss = 0.08879746
# Iteration 238, loss = 0.08161607
# Iteration 239, loss = 0.07801894
# Iteration 240, loss = 0.07607035
# Iteration 241, loss = 0.07743978
# Iteration 242, loss = 0.07116578
# Iteration 243, loss = 0.06562196
# Iteration 244, loss = 0.06490390
# Iteration 245, loss = 0.06317523
# Iteration 246, loss = 0.06372418
# Iteration 247, loss = 0.06092728
# Iteration 248, loss = 0.06226465
# Iteration 249, loss = 0.06474004
# Iteration 250, loss = 0.05935483
# Iteration 251, loss = 0.06336300
# Iteration 252, loss = 0.05617547
# Iteration 253, loss = 0.06018533
# Iteration 254, loss = 0.05549545
# Iteration 255, loss = 0.05888306
# Iteration 256, loss = 0.05434584
# Iteration 257, loss = 0.05196640
# Iteration 258, loss = 0.05084858
# Iteration 259, loss = 0.04927966
# Iteration 260, loss = 0.04853853
# Iteration 261, loss = 0.04728442
# Iteration 262, loss = 0.04717996
# Iteration 263, loss = 0.04757437
# Iteration 264, loss = 0.04676327
# Iteration 265, loss = 0.04574084
# Iteration 266, loss = 0.04529613
# Iteration 267, loss = 0.04463157
# Iteration 268, loss = 0.04547875
# Iteration 269, loss = 0.04493089
# Iteration 270, loss = 0.04341055
# Iteration 271, loss = 0.04164393
# Iteration 272, loss = 0.04225849
# Iteration 273, loss = 0.04782124
# Iteration 274, loss = 0.04570673
# Iteration 275, loss = 0.04183219
# Iteration 276, loss = 0.04408740
# Iteration 277, loss = 0.03940849
# Iteration 278, loss = 0.03795412
# Iteration 279, loss = 0.03822971
# Iteration 280, loss = 0.03812701
# Iteration 281, loss = 0.04205302
# Iteration 282, loss = 0.04049212
# Iteration 283, loss = 0.03627526
# Iteration 284, loss = 0.03601935
# Iteration 285, loss = 0.03639506
# Iteration 286, loss = 0.03687247
# Iteration 287, loss = 0.03585105
# Iteration 288, loss = 0.03702062
# Iteration 289, loss = 0.03341198
# Iteration 290, loss = 0.03369484
# Iteration 291, loss = 0.03752534
# Iteration 292, loss = 0.03345556
# Iteration 293, loss = 0.03147714
# Iteration 294, loss = 0.02967297
# Iteration 295, loss = 0.03274404
# Iteration 296, loss = 0.03014983
# Iteration 297, loss = 0.02971939
# Iteration 298, loss = 0.03007812
# Iteration 299, loss = 0.02882704
# Iteration 300, loss = 0.03062535
#   model  accuracy  precision  recall      f1
# 0   MLP    0.6753     0.6753  0.6753  0.6753

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_real.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.7338     0.7349  0.7338  0.7343
# 1   KNN    0.6883     0.6782  0.6883  0.6802
# 2    DT    0.7792     0.7835  0.7792  0.7808
# 3   SVM    0.4610     0.5452  0.4610  0.4600
# 4   MLP    0.6753     0.6753  0.6753  0.6753
