# %% [markdown]
# # TSTR CTGAN Dataset D

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home path of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'SYNTHETIC DATASETS/CTGAN/D_ContraceptiveMethod_Synthetic_CTGAN.csv')
categorical_columns = ['wife_education','husband_education','wife_religion','wife_working','husband_occupation',
                        'standard_of_living_index','media_exposure','contraceptive_method_used']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#       wife_age wife_education husband_education  children wife_religion  \
# 0           21              2                 4         3             1
# 1           19              3                 3         9             1
# 2           14              4                 4         2             1
# 3           26              4                 4         1             1
# 4           30              3                 4         0             1
# ...        ...            ...               ...       ...           ...
# 1173        20              1                 3         3             0
# 1174        16              1                 4         4             1
# 1175        40              4                 2         1             0
# 1176        34              3                 4         3             1
# 1177        41              3                 3         3             1
#
#      wife_working husband_occupation standard_of_living_index media_exposure  \
# 0               1                  3                        3              0
# 1               1                  1                        4              1
# 2               1                  1                        2              0
# 3               1                  1                        4              0
# 4               1                  2                        2              0
# ...           ...                ...                      ...            ...
# 1173            1                  3                        2              0
# 1174            0                  3                        2              0
# 1175            1                  1                        4              0
# 1176            1                  3                        2              0
# 1177            1                  1                        2              0
#
#      contraceptive_method_used
# 0                            3
# 1                            1
# 2                            3
# 3                            3
# 4                            2
# ...                        ...
# 1173                         1
# 1174                         3
# 1175                         3
# 1176                         3
# 1177                         1
#
# [1178 rows x 10 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/D_ContraceptiveMethod_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#      wife_age wife_education husband_education  children wife_religion  \
# 0          29              3                 3         4             1
# 1          35              3                 4         5             1
# 2          23              4                 4         1             0
# 3          30              2                 3         3             1
# 4          22              2                 3         1             1
# ..        ...            ...               ...       ...           ...
# 290        38              4                 4         3             1
# 291        25              2                 2         1             1
# 292        25              3                 1         4             1
# 293        24              4                 3         3             1
# 294        23              4                 3         2             1
#
#     wife_working husband_occupation standard_of_living_index media_exposure  \
# 0              1                  3                        4              0
# 1              0                  2                        2              0
# 2              1                  1                        4              0
# 3              1                  3                        1              0
# 4              1                  3                        3              0
# ..           ...                ...                      ...            ...
# 290            0                  1                        4              0
# 291            1                  3                        3              0
# 292            1                  3                        1              0
# 293            1                  3                        3              0
# 294            0                  2                        3              0
#
#     contraceptive_method_used
# 0                           3
# 1                           1
# 2                           2
# 3                           1
# 4                           1
# ..                        ...
# 290                         2
# 291                         3
# 292                         2
# 293                         3
# 294                         3
#
# [295 rows x 10 columns]

# %%
target = 'contraceptive_method_used'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (1178, 10)
# contraceptive_method_used
# 1    468
# 2    347
# 3    363
# dtype: int64
# #####################################
# Test data
# (295, 10)
# contraceptive_method_used
# 1    130
# 2     71
# 3     94
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'contraceptive_method_used'
categorical_columns = ['wife_education','husband_education','wife_religion','wife_working','husband_occupation',
                       'standard_of_living_index','media_exposure']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array([0, 1, 2, 3]), np.array([0, 1, 2, 3]), np.array([0, 1]), np.array([0, 1]), 
              np.array([0, 1, 2, 3]), np.array([0, 1, 2, 3]), np.array([0, 1])]

data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((1178, 24), (1178,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((295, 24), (295,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.0s finished
#   model  accuracy  precision  recall     f1
# 0    RF    0.4136     0.4118  0.4136  0.412

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.3729     0.3597  0.3729  0.3595

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.3424     0.3542  0.3424  0.3464

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.3864     0.3751  0.3864  0.3779

# %% [markdown]
# ## 8. Train and evaluate Multilayer Perceptron Classifier

# %%
mlp_results = train_evaluate_model('MLP', x_train, y_train, x_test, y_test)
results = results.append(mlp_results, ignore_index=True)
mlp_results
# Out:
# Iteration 1, loss = 1.10912507
# Iteration 2, loss = 1.08131333
# Iteration 3, loss = 1.07191198
# Iteration 4, loss = 1.06171623
# Iteration 5, loss = 1.05322127
# Iteration 6, loss = 1.04426663
# Iteration 7, loss = 1.03801883
# Iteration 8, loss = 1.03150799
# Iteration 9, loss = 1.02430214
# Iteration 197, loss = 0.10083175
# Iteration 198, loss = 0.09464214
# Iteration 199, loss = 0.09180544
# Iteration 200, loss = 0.09259022
# Iteration 201, loss = 0.08903568
# Iteration 202, loss = 0.08862895
# Iteration 203, loss = 0.08964526
# Iteration 204, loss = 0.08898667
# Iteration 205, loss = 0.09099979
# Iteration 206, loss = 0.08626121
# Iteration 207, loss = 0.08529106
# Iteration 208, loss = 0.08626003
# Iteration 209, loss = 0.08818135
# Iteration 210, loss = 0.08434210
# Iteration 211, loss = 0.08014983
# Iteration 212, loss = 0.08072412
# Iteration 213, loss = 0.08736117
# Iteration 214, loss = 0.08348242
# Iteration 215, loss = 0.08127153
# Iteration 216, loss = 0.08056845
# Iteration 217, loss = 0.08188666
# Iteration 218, loss = 0.07939476
# Iteration 219, loss = 0.08010008
# Iteration 220, loss = 0.08376080
# Iteration 221, loss = 0.07868119
# Iteration 222, loss = 0.08476767
# Iteration 223, loss = 0.07689082
# Iteration 224, loss = 0.07953416
# Iteration 225, loss = 0.07488407
# Iteration 226, loss = 0.07603621
# Iteration 227, loss = 0.07448660
# Iteration 228, loss = 0.07948926
# Iteration 229, loss = 0.07230723
# Iteration 230, loss = 0.08163808
# Iteration 231, loss = 0.07924984
# Iteration 232, loss = 0.07632361
# Iteration 233, loss = 0.07203636
# Iteration 234, loss = 0.07000225
# Iteration 235, loss = 0.06917452
# Iteration 236, loss = 0.06603118
# Iteration 237, loss = 0.06655095
# Iteration 238, loss = 0.06596243
# Iteration 239, loss = 0.06330796
# Iteration 240, loss = 0.06282013
# Iteration 241, loss = 0.06794155
# Iteration 242, loss = 0.07471929
# Iteration 243, loss = 0.06619948
# Iteration 244, loss = 0.06755800
# Iteration 245, loss = 0.06374786
# Iteration 246, loss = 0.06581794
# Iteration 247, loss = 0.06238381
# Iteration 248, loss = 0.06484895
# Iteration 249, loss = 0.06907092
# Iteration 250, loss = 0.06217958
# Iteration 251, loss = 0.06182248
# Iteration 252, loss = 0.05923965
# Iteration 253, loss = 0.05812632
# Iteration 254, loss = 0.05686917
# Iteration 255, loss = 0.05805056
# Iteration 256, loss = 0.05520660
# Iteration 257, loss = 0.05544080
# Iteration 258, loss = 0.05760210
# Iteration 259, loss = 0.05938400
# Iteration 260, loss = 0.05820436
# Iteration 261, loss = 0.05901220
# Iteration 262, loss = 0.05691028
# Iteration 263, loss = 0.05540011
# Iteration 264, loss = 0.05386353
# Iteration 265, loss = 0.05571450
# Iteration 266, loss = 0.05380840
# Iteration 267, loss = 0.05679185
# Iteration 268, loss = 0.06547200
# Iteration 269, loss = 0.07505411
# Iteration 270, loss = 0.06335244
# Iteration 271, loss = 0.07659451
# Iteration 272, loss = 0.08592188
# Iteration 273, loss = 0.06539125
# Iteration 274, loss = 0.07334695
# Iteration 275, loss = 0.06110944
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#   model  accuracy  precision  recall      f1
# 0   MLP    0.3932     0.3994  0.3932  0.3953

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_ctgan.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.4136     0.4118  0.4136  0.4120
# 1   KNN    0.3729     0.3597  0.3729  0.3595
# 2    DT    0.3424     0.3542  0.3424  0.3464
# 3   SVM    0.3864     0.3751  0.3864  0.3779
# 4   MLP    0.3932     0.3994  0.3932  0.3953
