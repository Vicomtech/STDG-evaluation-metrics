# %% [markdown]
# # TRTR Dataset B - Cardio

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home path of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TRAIN DATASETS/B_Cardio_Data_Real_Train.csv')
categorical_columns = ['gender','cholesterol','gluc','smoke','alco','active','cardio']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#           id    age gender  height  weight  ap_hi  ap_lo cholesterol gluc  \
# 0      67617  21876      1     154    80.0    130     90           2    1
# 1      96320  16717      2     162    70.0    140     90           1    1
# 2      17571  21128      2     174    92.0    150    100           1    1
# 3      46492  23366      2     173    76.0    120     82           1    1
# 4        945  20281      1     160    60.0    120     80           1    1
# ...      ...    ...    ...     ...     ...    ...    ...         ...  ...
# 55995  53137  16001      2     170    75.0    150     80           1    1
# 55996   8918  23209      2     162    73.0    160     90           1    1
# 55997  78302  23589      1     169    74.0    120     80           1    1
# 55998   1197  18227      1     167    70.0    120     80           1    1
# 55999  22556  15114      2     177    64.0    120     80           1    1
#
#       smoke alco active cardio
# 0         0    0      1      1
# 1         0    0      0      1
# 2         0    0      1      1
# 3         0    0      1      1
# 4         0    0      1      0
# ...     ...  ...    ...    ...
# 55995     1    0      1      1
# 55996     0    0      1      1
# 55997     0    0      1      0
# 55998     0    0      0      0
# 55999     0    0      1      0
#
# [56000 rows x 13 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/B_Cardio_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#           id    age gender  height  weight  ap_hi  ap_lo cholesterol gluc  \
# 0      66728  21770      1     156    64.0    140     80           2    1
# 1      69098  21876      1     170    85.0    160     90           1    1
# 2      59185  23270      1     151    90.0    130     80           1    1
# 3      49288  19741      1     159    97.0    120     80           1    1
# 4      62481  18395      1     164    68.0    120     80           1    1
# ...      ...    ...    ...     ...     ...    ...    ...         ...  ...
# 13995  30751  20490      2     172    70.0    120     80           1    1
# 13996  23253  16797      2     174    96.0    120     80           1    2
# 13997  34847  22607      1     165    66.0    110     80           1    1
# 13998  40118  19670      1     157    89.0    120     80           3    3
# 13999  90598  18320      2     176    83.0    140     90           1    1
#
#       smoke alco active cardio
# 0         0    0      1      1
# 1         0    0      1      1
# 2         0    0      1      1
# 3         0    0      1      1
# 4         0    0      1      0
# ...     ...  ...    ...    ...
# 13995     0    0      0      1
# 13996     0    0      1      1
# 13997     0    0      0      0
# 13998     0    0      1      1
# 13999     1    0      0      1
#
# [14000 rows x 13 columns]

# %%
target = 'cardio'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (56000, 13)
# cardio
# 0    28033
# 1    27967
# dtype: int64
# #####################################
# Test data
# (14000, 13)
# cardio
# 0    6988
# 1    7012
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'cardio'
categorical_columns = ['gender','cholesterol','gluc','smoke','alco','active']
numerical_columns = numerical_columns = train_data.select_dtypes(include=['int64']).columns.tolist()
categories = [np.array(range(2)), np.array(range(3)), np.array(range(3)), np.array(range(2)), np.array(range(2)), 
            np.array(range(2))]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((56000, 19), (56000,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((14000, 19), (14000,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.2s finished
#   model  accuracy  precision  recall      f1
# 0    RF    0.7139     0.7141  0.7139  0.7138

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.6504     0.6568  0.6504  0.6469

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.6343     0.6343  0.6343  0.6343

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.5006     0.6118  0.5006  0.3373

# %% [markdown]
# ## 8. Train and evaluate Multilayer Perceptron Classifier

# %%
mlp_results = train_evaluate_model('MLP', x_train, y_train, x_test, y_test)
results = results.append(mlp_results, ignore_index=True)
mlp_results
# Out:
# Iteration 1, loss = inf
# Iteration 2, loss = inf
# Iteration 3, loss = 0.54951042
# Iteration 4, loss = 0.54691666
# Iteration 5, loss = 0.54630366
# Iteration 6, loss = 0.54527458
# Iteration 7, loss = 0.54498814
# Iteration 8, loss = 0.54388112
# Iteration 9, loss = 0.54433403
# Iteration 10, loss = 0.54266721
# Iteration 11, loss = 0.54157524
# Iteration 12, loss = 0.54118756
# Iteration 13, loss = 0.54170565
# Iteration 14, loss = 0.54031526
# Iteration 15, loss = 0.54085046
# Iteration 16, loss = 0.54022206
# Iteration 17, loss = 0.54023308
# Iteration 18, loss = 0.53892197
# Iteration 19, loss = 0.53861417
# Iteration 20, loss = 0.53825106
# Iteration 21, loss = 0.53879218
# Iteration 22, loss = 0.53764884
# Iteration 23, loss = 0.53753162
# Iteration 24, loss = 0.53693925
# Iteration 25, loss = 0.53655625
# Iteration 26, loss = 0.53695441
# Iteration 27, loss = 0.53538187
# Iteration 28, loss = 0.53566733
# Iteration 29, loss = 0.53524642
# Iteration 30, loss = 0.53486497
# Iteration 31, loss = 0.53445025
# Iteration 32, loss = 0.53437499
# Iteration 33, loss = 0.53381048
# Iteration 34, loss = 0.53300145
# Iteration 35, loss = 0.53314928
# Iteration 36, loss = 0.53225224
# Iteration 37, loss = 0.53147751
# Iteration 38, loss = 0.53180289
# Iteration 39, loss = 0.53065187
# Iteration 40, loss = 0.53021081
# Iteration 41, loss = 0.52977643
# Iteration 42, loss = 0.53002165
# Iteration 43, loss = 0.52947054
# Iteration 44, loss = 0.52896346
# Iteration 45, loss = 0.52834025
# Iteration 46, loss = 0.52793282
# Iteration 47, loss = 0.52783435
# Iteration 48, loss = 0.52712865
# Iteration 49, loss = 0.52591949
# Iteration 50, loss = 0.52619638
# Iteration 51, loss = 0.52568128
# Iteration 52, loss = 0.52500713
# Iteration 53, loss = 0.52468435
# Iteration 54, loss = 0.52434192
# Iteration 55, loss = 0.52381261
# Iteration 56, loss = 0.52338972
# Iteration 57, loss = 0.52256567
# Iteration 58, loss = 0.52274988
# Iteration 59, loss = 0.52215163
# Iteration 60, loss = 0.52173032
# Iteration 61, loss = 0.52200096
# Iteration 62, loss = 0.52091062
# Iteration 63, loss = 0.52063540
# Iteration 64, loss = 0.51982122
# Iteration 65, loss = 0.51896866
# Iteration 66, loss = 0.51869552
# Iteration 67, loss = 0.51871026
# Iteration 68, loss = 0.51821970
# Iteration 69, loss = 0.51763551
# Iteration 70, loss = 0.51675902
# Iteration 234, loss = inf
# Iteration 235, loss = 0.45724053
# Iteration 236, loss = 0.45775250
# Iteration 237, loss = 0.45654304
# Iteration 238, loss = 0.45767373
# Iteration 239, loss = 0.45704946
# Iteration 240, loss = 0.45560673
# Iteration 241, loss = 0.45569647
# Iteration 242, loss = 0.45561890
# Iteration 243, loss = 0.45582411
# Iteration 244, loss = 0.45586228
# Iteration 245, loss = 0.45523641
# Iteration 246, loss = 0.45531055
# Iteration 247, loss = 0.45555089
# Iteration 248, loss = 0.45615192
# Iteration 249, loss = 0.45666229
# Iteration 250, loss = 0.45462927
# Iteration 251, loss = inf
# Iteration 252, loss = 0.45376714
# Iteration 253, loss = 0.45372551
# Iteration 254, loss = 0.45388997
# Iteration 255, loss = 0.45277754
# Iteration 256, loss = 0.45422247
# Iteration 257, loss = 0.45291108
# Iteration 258, loss = 0.45157557
# Iteration 259, loss = 0.45184580
# Iteration 260, loss = 0.45283443
# Iteration 261, loss = 0.45229411
# Iteration 262, loss = 0.45219451
# Iteration 263, loss = 0.45172128
# Iteration 264, loss = 0.45128517
# Iteration 265, loss = 0.45032712
# Iteration 266, loss = 0.45160933
# Iteration 267, loss = 0.45011150
# Iteration 268, loss = 0.45089274
# Iteration 269, loss = 0.45084411
# Iteration 270, loss = 0.44978177
# Iteration 271, loss = 0.44913017
# Iteration 272, loss = 0.44974921
# Iteration 273, loss = 0.44832500
# Iteration 274, loss = 0.44870205
# Iteration 275, loss = inf
# Iteration 276, loss = 0.44973440
# Iteration 277, loss = 0.44835574
# Iteration 278, loss = 0.44770747
# Iteration 279, loss = 0.44849392
# Iteration 280, loss = 0.44932048
# Iteration 281, loss = 0.44846856
# Iteration 282, loss = 0.44730814
# Iteration 283, loss = 0.44676729
# Iteration 284, loss = 0.44854871
# Iteration 285, loss = inf
# Iteration 286, loss = 0.44760049
# Iteration 287, loss = 0.44685418
# Iteration 288, loss = 0.44627394
# Iteration 289, loss = 0.44623140
# Iteration 290, loss = 0.44537846
# Iteration 291, loss = 0.44668693
# Iteration 292, loss = 0.44508576
# Iteration 293, loss = 0.44522621
# Iteration 294, loss = 0.44453424
# Iteration 295, loss = inf
# Iteration 296, loss = 0.44602392
# Iteration 297, loss = 0.44565435
# Iteration 298, loss = 0.44451577
# Iteration 299, loss = 0.44443492
# Iteration 300, loss = 0.44451233
#   model  accuracy  precision  recall     f1
# 0   MLP    0.7036     0.7054  0.7036  0.703

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_real.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.7139     0.7141  0.7139  0.7138
# 1   KNN    0.6504     0.6568  0.6504  0.6469
# 2    DT    0.6343     0.6343  0.6343  0.6343
# 3   SVM    0.5006     0.6118  0.5006  0.3373
# 4   MLP    0.7036     0.7054  0.7036  0.7030
