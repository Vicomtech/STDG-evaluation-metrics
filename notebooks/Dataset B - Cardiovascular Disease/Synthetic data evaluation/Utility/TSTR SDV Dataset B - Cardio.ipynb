# %% [markdown]
# # TSTR SDV Dataset B - Cardio

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home path of the project
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'SYNTHETIC DATASETS/SDV/B_Cardio_Data_Synthetic_SDV.csv')
categorical_columns = ['gender','cholesterol','gluc','smoke','alco','active','cardio']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#           id    age gender  height  weight  ap_hi  ap_lo cholesterol gluc  \
# 0      24346  15207      1     159   106.0    226     58           1    1
# 1      26676  17505      1     162    55.3     70    241           1    1
# 2      49760  20801      1     166    61.4    195     -9           1    1
# 3      14459  16731      1     150    55.8      1     51           1    1
# 4      52249  19696      1     154    69.1    -75     71           1    1
# ...      ...    ...    ...     ...     ...    ...    ...         ...  ...
# 55995  78730  17842      2     177    52.6    260    233           2    1
# 55996  41123  18471      1     171   110.0     94    273           1    1
# 55997  68825  18308      1     168    48.4     25    423           1    1
# 55998  45094  17022      1     161    87.5     -7    202           2    1
# 55999  89629  18680      1     167    70.0    218   -202           1    1
#
#       smoke alco active cardio
# 0         0    0      1      1
# 1         0    0      1      1
# 2         0    0      1      1
# 3         0    0      1      1
# 4         0    0      0      1
# ...     ...  ...    ...    ...
# 55995     0    0      0      1
# 55996     0    0      1      1
# 55997     0    0      1      0
# 55998     0    0      1      1
# 55999     0    0      0      1
#
# [56000 rows x 13 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/B_Cardio_Data_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#           id    age gender  height  weight  ap_hi  ap_lo cholesterol gluc  \
# 0      66728  21770      1     156    64.0    140     80           2    1
# 1      69098  21876      1     170    85.0    160     90           1    1
# 2      59185  23270      1     151    90.0    130     80           1    1
# 3      49288  19741      1     159    97.0    120     80           1    1
# 4      62481  18395      1     164    68.0    120     80           1    1
# ...      ...    ...    ...     ...     ...    ...    ...         ...  ...
# 13995  30751  20490      2     172    70.0    120     80           1    1
# 13996  23253  16797      2     174    96.0    120     80           1    2
# 13997  34847  22607      1     165    66.0    110     80           1    1
# 13998  40118  19670      1     157    89.0    120     80           3    3
# 13999  90598  18320      2     176    83.0    140     90           1    1
#
#       smoke alco active cardio
# 0         0    0      1      1
# 1         0    0      1      1
# 2         0    0      1      1
# 3         0    0      1      1
# 4         0    0      1      0
# ...     ...  ...    ...    ...
# 13995     0    0      0      1
# 13996     0    0      1      1
# 13997     0    0      0      0
# 13998     0    0      1      1
# 13999     1    0      0      1
#
# [14000 rows x 13 columns]

# %%
target = 'cardio'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (56000, 13)
# cardio
# 0    10888
# 1    45112
# dtype: int64
# #####################################
# Test data
# (14000, 13)
# cardio
# 0    6988
# 1    7012
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'cardio'
categorical_columns = ['gender','cholesterol','gluc','smoke','alco','active']
numerical_columns = numerical_columns = train_data.select_dtypes(include=['int64']).columns.tolist()
categories = [np.array(range(2)), np.array(range(3)), np.array(range(3)), np.array(range(2)), np.array(range(2)), 
            np.array(range(2))]


data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((56000, 19), (56000,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((14000, 19), (14000,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:   16.3s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.5s finished
#   model  accuracy  precision  recall      f1
# 0    RF     0.502     0.6255   0.502  0.3378

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.5121     0.5855  0.5121  0.3766

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.5017     0.5017  0.5017  0.4697

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall     f1
# 0   SVM    0.4532     0.4505  0.4532  0.446

# %% [markdown]
# ## 8. Train and evaluate Multilayer Perceptron Classifier

# %%
mlp_results = train_evaluate_model('MLP', x_train, y_train, x_test, y_test)
results = results.append(mlp_results, ignore_index=True)
mlp_results
# Out:
# Iteration 1, loss = 0.46936531
# Iteration 2, loss = 0.46368409
# Iteration 3, loss = 0.46342770
# Iteration 4, loss = 0.46320132
# Iteration 5, loss = 0.46295659
# Iteration 185, loss = 0.36622180
# Iteration 186, loss = 0.36606573
# Iteration 187, loss = 0.36642835
# Iteration 188, loss = 0.36348255
# Iteration 189, loss = 0.36482765
# Iteration 190, loss = 0.36416699
# Iteration 191, loss = 0.36489245
# Iteration 192, loss = 0.36461075
# Iteration 193, loss = 0.36509415
# Iteration 194, loss = 0.36385688
# Iteration 195, loss = 0.36244914
# Iteration 196, loss = 0.36366906
# Iteration 197, loss = 0.36264460
# Iteration 198, loss = 0.36264121
# Iteration 199, loss = 0.36240169
# Iteration 200, loss = 0.36271837
# Iteration 201, loss = 0.36372551
# Iteration 202, loss = 0.36268399
# Iteration 203, loss = 0.36080929
# Iteration 204, loss = 0.35984328
# Iteration 205, loss = 0.36001333
# Iteration 206, loss = 0.36036654
# Iteration 207, loss = 0.35877682
# Iteration 208, loss = 0.35875392
# Iteration 209, loss = 0.35964055
# Iteration 210, loss = 0.36005959
# Iteration 211, loss = 0.35854415
# Iteration 212, loss = 0.35895788
# Iteration 213, loss = 0.35692457
# Iteration 214, loss = 0.35779338
# Iteration 215, loss = 0.35736089
# Iteration 216, loss = 0.35742125
# Iteration 217, loss = 0.35770718
# Iteration 218, loss = 0.35873924
# Iteration 219, loss = 0.35570383
# Iteration 220, loss = 0.35552209
# Iteration 221, loss = 0.35644760
# Iteration 222, loss = 0.35629604
# Iteration 223, loss = 0.35619577
# Iteration 224, loss = 0.35589581
# Iteration 225, loss = 0.35500832
# Iteration 226, loss = 0.35435706
# Iteration 227, loss = 0.35446851
# Iteration 228, loss = 0.35494424
# Iteration 229, loss = 0.35509386
# Iteration 230, loss = 0.35355969
# Iteration 231, loss = 0.35390539
# Iteration 232, loss = 0.35385480
# Iteration 233, loss = 0.35247265
# Iteration 234, loss = 0.35362000
# Iteration 235, loss = 0.35370046
# Iteration 236, loss = 0.35302551
# Iteration 237, loss = 0.35253261
# Iteration 238, loss = 0.35224393
# Iteration 239, loss = 0.35161982
# Iteration 240, loss = 0.35102837
# Iteration 241, loss = 0.35079477
# Iteration 242, loss = 0.35233282
# Iteration 243, loss = 0.35220700
# Iteration 244, loss = 0.35133236
# Iteration 245, loss = 0.34919198
# Iteration 246, loss = 0.35162279
# Iteration 247, loss = 0.34948443
# Iteration 248, loss = 0.34767978
# Iteration 249, loss = 0.34892960
# Iteration 250, loss = 0.34940495
# Iteration 251, loss = 0.35015514
# Iteration 252, loss = 0.34961224
# Iteration 253, loss = 0.34774643
# Iteration 254, loss = 0.34915822
# Iteration 255, loss = 0.34849736
# Iteration 256, loss = 0.34914641
# Iteration 257, loss = 0.34760370
# Iteration 258, loss = 0.34871374
# Iteration 259, loss = 0.34831432
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#   model  accuracy  precision  recall     f1
# 0   MLP    0.5082     0.5273  0.5082  0.399

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_sdv.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.5020     0.6255  0.5020  0.3378
# 1   KNN    0.5121     0.5855  0.5121  0.3766
# 2    DT    0.5017     0.5017  0.5017  0.4697
# 3   SVM    0.4532     0.4505  0.4532  0.4460
# 4   MLP    0.5082     0.5273  0.5082  0.3990
