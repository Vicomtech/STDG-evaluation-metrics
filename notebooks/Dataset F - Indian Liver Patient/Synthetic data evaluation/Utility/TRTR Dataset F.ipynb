# %% [markdown]
# # TRTR Dataset F

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = '' #home path of the project
FUNCTIONS_DIR = "EVALUATION FUNCTIONS/UTILITY"
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TRAIN DATASETS/F_IndianLiverPatient_Real_Train.csv')
categorical_columns = ['gender','class']
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#      age  gender   TB   DB  alkphos  sgpt   sgot   TP  ALB   A_G class
# 0     68  Female  0.6  0.1   1620.0  95.0  127.0  4.6  2.1  0.80   1.0
# 1     31    Male  1.3  0.5    184.0  29.0   32.0  6.8  3.4  1.00   1.0
# 2     28    Male  0.8  0.3    190.0  20.0   14.0  4.1  2.4  1.40   1.0
# 3     60    Male  2.3  0.6    272.0  79.0   51.0  6.6  3.5  1.10   1.0
# 4     48  Female  0.9  0.2    173.0  26.0   27.0  6.2  3.1  1.00   1.0
# ..   ...     ...  ...  ...      ...   ...    ...  ...  ...   ...   ...
# 461   75  Female  0.8  0.2    188.0  20.0   29.0  4.4  1.8  0.60   1.0
# 462   36    Male  5.3  2.3    145.0  32.0   92.0  5.1  2.6  1.00   2.0
# 463   37    Male  0.7  0.2    235.0  96.0   54.0  9.5  4.9  1.00   1.0
# 464   17  Female  0.5  0.1    206.0  28.0   21.0  7.1  4.5  1.70   2.0
# 465   17    Male  0.9  0.2    224.0  36.0   45.0  6.9  4.2  1.55   1.0
#
# [466 rows x 11 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'REAL DATASETS/TEST DATASETS/F_IndianLiverPatient_Real_Test.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#      age  gender    TB   DB  alkphos   sgpt   sgot   TP  ALB        A_G class
# 0     19    Male   1.4  0.8    178.0   13.0   26.0  8.0  4.6       1.30   2.0
# 1     12    Male   1.0  0.2    719.0  157.0  108.0  7.2  3.7       1.00   1.0
# 2     60    Male   5.7  2.8    214.0  412.0  850.0  7.3  3.2       0.78   1.0
# 3     42  Female   0.5  0.1    162.0  155.0  108.0  8.1  4.0       0.90   1.0
# 4     40    Male  14.5  6.4    358.0   50.0   75.0  5.7  2.1       0.50   1.0
# ..   ...     ...   ...  ...      ...    ...    ...  ...  ...        ...   ...
# 112   60    Male   0.9  0.3    168.0   16.0   24.0  6.7  3.0       0.80   1.0
# 113   54  Female   1.4  0.7    195.0   36.0   16.0  7.9  3.7       0.90   2.0
# 114   47  Female   3.0  1.5    292.0   64.0   67.0  5.6  1.8       0.47   1.0
# 115   27    Male   1.3  0.6    106.0   25.0   54.0  8.5  4.8 -100000.00   2.0
# 116   21    Male   0.7  0.2    211.0   14.0   23.0  7.3  4.1       1.20   2.0
#
# [117 rows x 11 columns]

# %%
target = 'class'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (466, 11)
# class
# 1.0    329
# 2.0    137
# dtype: int64
# #####################################
# Test data
# (117, 11)
# class
# 1.0    87
# 2.0    30
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = 'class'
categorical_columns = ['gender']
numerical_columns = train_data.select_dtypes(include=['int64','float64']).columns.tolist()
categories = [np.array([0, 1])]

data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((466, 11), (466,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((117, 11), (117,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = results.append(rf_results, ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.0s finished
#   model  accuracy  precision  recall      f1
# 0    RF    0.7607     0.7426  0.7607  0.7475

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = results.append(knn_results, ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.7436     0.7018  0.7436  0.7007

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = results.append(dt_results, ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.7179     0.7475  0.7179  0.7287

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = results.append(svm_results, ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.6581     0.6801  0.6581  0.6676

# %% [markdown]
# ## 8. Train and evaluate Multilayer Perceptron Classifier

# %%
mlp_results = train_evaluate_model('MLP', x_train, y_train, x_test, y_test)
results = results.append(mlp_results, ignore_index=True)
mlp_results
# Out:
# Iteration 1, loss = 0.67684747
# Iteration 2, loss = 0.62090094
# Iteration 3, loss = 0.58824317
# Iteration 4, loss = 0.57354684
# Iteration 5, loss = 0.56279411
# Iteration 6, loss = 0.55452898
# Iteration 7, loss = 0.54609816
# Iteration 8, loss = 0.53939953
# Iteration 9, loss = 0.53355816
# Iteration 10, loss = 0.52847297
# Iteration 11, loss = 0.52400344
# Iteration 12, loss = 0.51974075
# Iteration 13, loss = 0.51606170
# Iteration 14, loss = 0.51218961
# Iteration 15, loss = 0.50860828
# Iteration 16, loss = 0.50581889
# Iteration 17, loss = 0.50338018
# Iteration 18, loss = 0.50140738
# Iteration 19, loss = 0.49883992
# Iteration 20, loss = 0.49603732
# Iteration 21, loss = 0.49370245
# Iteration 22, loss = 0.49137711
# Iteration 23, loss = 0.48942830
# Iteration 24, loss = 0.48785787
# Iteration 25, loss = 0.48697543
# Iteration 26, loss = 0.48481880
# Iteration 27, loss = 0.48225034
# Iteration 28, loss = 0.48094626
# Iteration 29, loss = 0.47879157
# Iteration 30, loss = 0.47691087
# Iteration 31, loss = 0.47542083
# Iteration 32, loss = 0.47366905
# Iteration 33, loss = 0.47197920
# Iteration 34, loss = 0.47044233
# Iteration 35, loss = 0.46854968
# Iteration 36, loss = 0.46705413
# Iteration 37, loss = 0.46573184
# Iteration 38, loss = 0.46501385
# Iteration 39, loss = 0.46214404
# Iteration 40, loss = 0.46191452
# Iteration 41, loss = 0.45979586
# Iteration 42, loss = 0.45686607
# Iteration 43, loss = 0.45704165
# Iteration 44, loss = 0.45780731
# Iteration 45, loss = 0.45310529
# Iteration 46, loss = 0.45159431
# Iteration 47, loss = 0.44980694
# Iteration 48, loss = 0.44797377
# Iteration 49, loss = 0.44837914
# Iteration 50, loss = 0.44533795
# Iteration 51, loss = 0.44455874
# Iteration 52, loss = 0.44392555
# Iteration 53, loss = 0.43846378
# Iteration 54, loss = 0.43660961
# Iteration 55, loss = 0.43619986
# Iteration 56, loss = 0.43271781
# Iteration 57, loss = 0.43081367
# Iteration 58, loss = 0.42975715
# Iteration 59, loss = 0.42783343
# Iteration 60, loss = 0.42596277
# Iteration 61, loss = 0.42396416
# Iteration 62, loss = 0.42315172
# Iteration 63, loss = 0.41922694
# Iteration 64, loss = 0.41700231
# Iteration 65, loss = 0.41523662
# Iteration 66, loss = 0.41246564
# Iteration 67, loss = 0.41044091
# Iteration 68, loss = 0.40900772
# Iteration 69, loss = 0.40664081
# Iteration 70, loss = 0.40415945
# Iteration 71, loss = 0.40169395
# Iteration 72, loss = 0.40100788
# Iteration 235, loss = 0.11097087
# Iteration 236, loss = 0.10968632
# Iteration 237, loss = 0.10201144
# Iteration 238, loss = 0.11318616
# Iteration 239, loss = 0.11057118
# Iteration 240, loss = 0.10766616
# Iteration 241, loss = 0.10169733
# Iteration 242, loss = 0.10619772
# Iteration 243, loss = 0.11322898
# Iteration 244, loss = 0.10858673
# Iteration 245, loss = 0.09912899
# Iteration 246, loss = 0.10248126
# Iteration 247, loss = 0.10105911
# Iteration 248, loss = 0.10178917
# Iteration 249, loss = 0.10719033
# Iteration 250, loss = 0.10152414
# Iteration 251, loss = 0.10332652
# Iteration 252, loss = 0.09709987
# Iteration 253, loss = 0.09567243
# Iteration 254, loss = 0.08915604
# Iteration 255, loss = 0.09201349
# Iteration 256, loss = 0.09421535
# Iteration 257, loss = 0.09218254
# Iteration 258, loss = 0.09684618
# Iteration 259, loss = 0.08961444
# Iteration 260, loss = 0.09446925
# Iteration 261, loss = 0.08790131
# Iteration 262, loss = 0.08939892
# Iteration 263, loss = 0.08822077
# Iteration 264, loss = 0.09403138
# Iteration 265, loss = 0.08688092
# Iteration 266, loss = 0.09277440
# Iteration 267, loss = 0.09541135
# Iteration 268, loss = 0.09024705
# Iteration 269, loss = 0.08548965
# Iteration 270, loss = 0.09267999
# Iteration 271, loss = 0.08985033
# Iteration 272, loss = 0.09195042
# Iteration 273, loss = 0.08735192
# Iteration 274, loss = 0.07954082
# Iteration 275, loss = 0.08067109
# Iteration 276, loss = 0.07650995
# Iteration 277, loss = 0.08377020
# Iteration 278, loss = 0.07707321
# Iteration 279, loss = 0.07674919
# Iteration 280, loss = 0.07723468
# Iteration 281, loss = 0.07304240
# Iteration 282, loss = 0.07556999
# Iteration 283, loss = 0.08032555
# Iteration 284, loss = 0.07301000
# Iteration 285, loss = 0.07191761
# Iteration 286, loss = 0.06983139
# Iteration 287, loss = 0.07153136
# Iteration 288, loss = 0.06884587
# Iteration 289, loss = 0.07108800
# Iteration 290, loss = 0.06753022
# Iteration 291, loss = 0.06817251
# Iteration 292, loss = 0.06851664
# Iteration 293, loss = 0.06906039
# Iteration 294, loss = 0.06909832
# Iteration 295, loss = 0.06831138
# Iteration 296, loss = 0.06749041
# Iteration 297, loss = 0.06425962
# Iteration 298, loss = 0.06575291
# Iteration 299, loss = 0.06792926
# Iteration 300, loss = 0.06640261
#   model  accuracy  precision  recall      f1
# 0   MLP    0.7265     0.7388  0.7265  0.7318

# %% [markdown]
# ## 9. Save results file

# %%
results.to_csv('RESULTS/models_results_real.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.7607     0.7426  0.7607  0.7475
# 1   KNN    0.7436     0.7018  0.7436  0.7007
# 2    DT    0.7179     0.7475  0.7179  0.7287
# 3   SVM    0.6581     0.6801  0.6581  0.6676
# 4   MLP    0.7265     0.7388  0.7265  0.7318
